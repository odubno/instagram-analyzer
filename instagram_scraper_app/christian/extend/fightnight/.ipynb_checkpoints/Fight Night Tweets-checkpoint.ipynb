# %%
false = 'false'
null = 'null'
true = 'true'

# %%
test = {"created_at":"Sat May 02 01:36:51 +0000 2015","id_str":"594314574561714178","text":"Manny Pacquiao Is a Terrible Congressman. Good Thing He Never Shows Up for Work. http:\/\/t.co\/3aQPnqmal4 via @slate","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":291774022,"id_str":"291774022","name":"JoeInWV","screen_name":"wvjoe911","location":"West Virginia","url":null,"description":"Proud Liberal, #GunSense, USAF Vet., Retired 911 Opr,    #LGBT  #UniteBlue   #Equality  #HILLARY2016 #NoWayNRA \n I Block #RWNJ's & #Ammosexuals #LegalizeIt","protected":false,"verified":false,"followers_count":7401,"friends_count":7286,"listed_count":158,"favourites_count":4152,"statuses_count":80006,"created_at":"Mon May 02 15:59:23 +0000 2011","utc_offset":-14400,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"352726","profile_background_image_url":"http:\/\/pbs.twimg.com\/profile_background_images\/336218402\/2011-08-19_14.14.59.jpg","profile_background_image_url_https":"https:\/\/pbs.twimg.com\/profile_background_images\/336218402\/2011-08-19_14.14.59.jpg","profile_background_tile":false,"profile_link_color":"D02B55","profile_sidebar_border_color":"829D5E","profile_sidebar_fill_color":"99CC33","profile_text_color":"3E4415","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/560949135633702912\/3fkW7acD_normal.png","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/560949135633702912\/3fkW7acD_normal.png","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/291774022\/1395526612","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"trends":[],"urls":[{"url":"http:\/\/t.co\/3aQPnqmal4","expanded_url":"http:\/\/www.slate.com\/blogs\/the_slatest\/2015\/05\/01\/manny_pacquiao_is_a_terrible_congressman_good_thing_he_never_shows_up_for.html?wpsrc=sh_all_dt_tw_top","display_url":"slate.com\/blogs\/the_slat\u2026","indices":[81,103]}],"user_mentions":[{"screen_name":"Slate","name":"Slate","id":15164565,"id_str":"15164565","indices":[108,114]}],"symbols":[]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en","timestamp_ms":"1430530611063"}

# %%
test
# Out:
# {'contributors': 'null',
#  'coordinates': 'null',
#  'created_at': 'Sat May 02 01:36:51 +0000 2015',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'trends': [],
#   'urls': [{'display_url': 'slate.com\\/blogs\\/the_slat\\u2026',
#     'expanded_url': 'http:\\/\\/www.slate.com\\/blogs\\/the_slatest\\/2015\\/05\\/01\\/manny_pacquiao_is_a_terrible_congressman_good_thing_he_never_shows_up_for.html?wpsrc=sh_all_dt_tw_top',
#     'indices': [81, 103],
#     'url': 'http:\\/\\/t.co\\/3aQPnqmal4'}],
#   'user_mentions': [{'id': 15164565,
#     'id_str': '15164565',
#     'indices': [108, 114],
#     'name': 'Slate',
#     'screen_name': 'Slate'}]},
#  'favorite_count': 0,
#  'favorited': 'false',
#  'filter_level': 'low',
#  'geo': 'null',
#  'id_str': '594314574561714178',
#  'in_reply_to_screen_name': 'null',
#  'in_reply_to_status_id': 'null',
#  'in_reply_to_status_id_str': 'null',
#  'in_reply_to_user_id': 'null',
#  'in_reply_to_user_id_str': 'null',
#  'lang': 'en',
#  'place': 'null',
#  'possibly_sensitive': 'false',
#  'retweet_count': 0,
#  'retweeted': 'false',
#  'source': '\\u003ca href="http:\\/\\/twitter.com" rel="nofollow"\\u003eTwitter Web Client\\u003c\\/a\\u003e',
#  'text': 'Manny Pacquiao Is a Terrible Congressman. Good Thing He Never Shows Up for Work. http:\\/\\/t.co\\/3aQPnqmal4 via @slate',
#  'timestamp_ms': '1430530611063',
#  'truncated': 'false',
#  'user': {'contributors_enabled': 'false',
#   'created_at': 'Mon May 02 15:59:23 +0000 2011',
#   'default_profile': 'false',
#   'default_profile_image': 'false',
#   'description': "Proud Liberal, #GunSense, USAF Vet., Retired 911 Opr,    #LGBT  #UniteBlue   #Equality  #HILLARY2016 #NoWayNRA \n I Block #RWNJ's & #Ammosexuals #LegalizeIt",
#   'favourites_count': 4152,
#   'follow_request_sent': 'null',
#   'followers_count': 7401,
#   'following': 'null',
#   'friends_count': 7286,
#   'geo_enabled': 'true',
#   'id': 291774022,
#   'id_str': '291774022',
#   'is_translator': 'false',
#   'lang': 'en',
#   'listed_count': 158,
#   'location': 'West Virginia',
#   'name': 'JoeInWV',
#   'notifications': 'null',
#   'profile_background_color': '352726',
#   'profile_background_image_url': 'http:\\/\\/pbs.twimg.com\\/profile_background_images\\/336218402\\/2011-08-19_14.14.59.jpg',
#   'profile_background_image_url_https': 'https:\\/\\/pbs.twimg.com\\/profile_background_images\\/336218402\\/2011-08-19_14.14.59.jpg',
#   'profile_background_tile': 'false',
#   'profile_banner_url': 'https:\\/\\/pbs.twimg.com\\/profile_banners\\/291774022\\/1395526612',
#   'profile_image_url': 'http:\\/\\/pbs.twimg.com\\/profile_images\\/560949135633702912\\/3fkW7acD_normal.png',
#   'profile_image_url_https': 'https:\\/\\/pbs.twimg.com\\/profile_images\\/560949135633702912\\/3fkW7acD_normal.png',
#   'profile_link_color': 'D02B55',
#   'profile_sidebar_border_color': '829D5E',
#   'profile_sidebar_fill_color': '99CC33',
#   'profile_text_color': '3E4415',
#   'profile_use_background_image': 'true',
#   'protected': 'false',
#   'screen_name': 'wvjoe911',
#   'statuses_count': 80006,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'url': 'null',
#   'utc_offset': -14400,
#   'verified': 'false'}}

# %%
import pandas as pd
import json
from bs4 import BeautifulSoup as bs

# %%
#12 columns

# %%
data = 'boxingtweets.csv'

# %%
df = pd.read_csv(data)
df = df.fillna('')
df['Tweet'] = df['Tweet'].map(str) + ',' + df['tweet_2'].map(str) + ',' + df['tweet_3'].map(str) + ',' + df['tweet_4'].map(str) + ',' + df['tweet_5'].map(str) + ',' + df['tweet_6'].map(str) + ',' + ',' + df['tweet_7'].map(str) + ',' + df['tweet_8'].map(str) + ',' + df['tweet_9'].map(str) + ',' + df['tweet_10'].map(str) + ',' + df['tweet_11'].map(str) + ',' + df['tweet_12'].map(str)  + ',' + df['tweet_13'].map(str) 
df = df.drop([x for x in df.columns[3:-1]], axis=1)
df = df[['Timestamp','User','Tweet']]
df = df[[x[-4:] == '2015' for x in df['Timestamp']]]

# %%
df
# Out:
#                             Timestamp               User  \
# 0      Sat May 02 18:33:55 +0000 2015   @xkorrinhastings
# 1      Sat May 02 18:33:55 +0000 2015   @AnnieOntheRadio
# 2      Sat May 02 18:33:56 +0000 2015   @LeftistPolitics
# 3      Sat May 02 18:33:56 +0000 2015           @jethang
# 4      Sat May 02 18:33:57 +0000 2015     @patrickgiblin
# 5      Sat May 02 18:33:57 +0000 2015            @TVSH_P
# 6      Sat May 02 18:33:57 +0000 2015       @YahooSchwab
# 7      Sat May 02 18:33:58 +0000 2015          @EzViper_
# 8      Sat May 02 18:33:58 +0000 2015         @MKGolden_
# 9      Sat May 02 18:33:58 +0000 2015          @k9spence
# 10     Sat May 02 18:33:59 +0000 2015             @WYWTV
# 11     Sat May 02 18:33:59 +0000 2015       @Ally10craig
# 12     Sat May 02 18:33:59 +0000 2015         @WMRiley89
# 13     Sat May 02 18:33:59 +0000 2015       @DaRandomAkh
# 4       Could care less about the "sport" of boxing. ...
# 5       Yall not slick tweeting valid points about bo...
# 6       @kevincharles999 Oh no, he loses a boxing mat...
# 7       I think Mayweather will win the boxing :) ,,,...
# 8       Then there's people who claim to know boxing....
# 9       I'd love to have mates to watch the boxing wi...
# 10      WATCH #BOXING #MAYPAC PPV FOR ONLY $9.99 AT h...
# 11      @hartson32 @dawmillar @alexshaw79 @paulcraven...
# 12      Tipple for the boxing tonight. #Belverdere #B...
# 13      HELPPPPPP!!!  #AlAin #UAE #Dubai #DXB #Sharja...
# 14      Details of @BBC5Live's coverage of tonight's ...
# 16      No chance I'll be able to stay awake for the ...
# 17      What is this boxing match nonsense you hetero...
# 18      Got the beer and nibbles in for boxing :-) ,,...
# 19      @abeyptfc @Aldojags im looking to get into a ...
# 20            Yall swear yall watch boxing ,,,,,,,,,,,,,
# 21      #HIPHOP #Celebrity #BOXING #LasVEGAS http://t...
# 22      #Tonight #boxing #FightWeekend  https://t.co/...
# 23      #HIPHOP #Celebrity #BOXING #LasVEGAS http://t...
# 24      People need to stop putting their life saving...
# 25      The wait is over. #FloydMayweather will fight...
# 26      God forbid that I put on gen in the middle of...
# 27      #Dortmund for the #KentuckyDerby2015  &amp; #...
# 28      Somehow gonna watch the boxing at 4am ,,,,,,,...
# 29      @NNNJdot I just like that manny is aggressive...
# 30      Ngl I'm not a huge fan of boxing but looking ...
# ...                                                  ...
# 68754   And some people ask me why I hate boxing. Was...
# 68755   Great night for sports between track and boxi...
# 68756                       Fucking boxing ,,,,,,,,,,,,,
# 68757   Pele "@Carlo_Larenzo: This is bullshit, I'd n...
# 68759   Fuck this world off boxing man, corruption #M...
# 68760   So from now on! The boxing is all about runni...
# 68762   Bullshit to! Hanggang sa boxing walang justic...
# 68763   hindi yan luto, boxing yan mga ulul haha ,,,,...
# 68764   One thing I learned, never watch a boxing mat...
# 68765   If you THROW 7 less punches than the man who ...
# 68766   @RealDill2323 Lol I think boxing died when Ty...
# 68767   Man the Internet Is ruthless, Like you try bo...
# 68768   To those that don't regularly follow boxing; ...
# 68769   Y'all wanna see somebody pull out a knife or ...
# 68770   i've never watched boxing before but i was so...
# 68771   everybody gonna forget about boxing after ton...
# 68772   People watch boxing anticipating a street fig...
# 68773   Boxing needs a Julio Cesar Chavez a Mike Tyso...
# 68774   #Boxing: Judges scored the fight for Floyd Ma...
# 68775   If I can win boxing by hugging than sign me u...
# 68776   @SenseiCell @missfree pssh..if u cant respect...
# 68777   If you base it on the official boxing rules. ...
# 68778   @way2bored4dis Shut your nutty ass up you pro...
# 68779   Now I remember why I watch wrestling instead ...
# 68780   @vaaaaleeriiia if boxing weren't fixed.. ,,,,...
# 68781   SANA NAMAN NA-INFORM NIYO SI MAYWEATHER NA BO...
# 68783   MMA IS BETTER THEN BOXING!!!! Yeah I said it....
# 68784   "@jaykillaaaa: How Many Of Yall Females Actua...
# 68785   A new boxing rule should be up! Box until the...
# 68786   Exactly what I said  https://t.co/J3yiEP0KhS ...
#
# [61459 rows x 3 columns]

# %%
word = ''
str(float(len(df[[word in x. for x in df.Tweet]]))/float(len(df))*100)[:4]+"% of tweets from a random twitter sample collected during the fight contained the word: "+word
# Out:
# '0.21% of tweets from a random twitter sample collected during the fight contained the word: base'
