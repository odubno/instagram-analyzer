# %%
from instagram_analyze_json_DataFrame import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-2acbf5bd7678> in <module>()
# ----> 1 from instagram_analyze_json_DataFrame import *
#
# ImportError: No module named instagram_analyze_json_DataFrame

# %%
import os
os.getcwd()
# Out:
# '/Users/olehdubno/Desktop/Instagram_Scraper/IPython_Notebook_Files'
