# %%
from instagram.client import InstagramAPI


api = InstagramAPI(access_token=access_token)
recent_media, next_ = api.user_recent_media(user_id="userid", count=10)
for media in recent_media:
   print media.caption.text

# %%
api = InstagramAPI(client_id=client_id, client_secret=secret)
popular_media = api.media_popular(count=20)
#for media in popular_media:
    #print media.comment_count, media.comments

# %%
#when you query for a specific hashtag (e.g. 'newyorkcity')
#how many likes did a post get; likes
#captions
#tags *
#total amount of comments
#user
#filter *
#type of media *
#time *
#location *
#link *

# %%
from pandas.io.json import json_normalize
import pandas as pd
import requests
import json
from glasses import *

base_url = "https://api.instagram.com/v1"
query = "tombrown"

url = '{0}/tags/{1}/media/recent?client_id={2}&count=100'.format(base_url, query, client_id)

df = json_normalize(requests.get(url).json()['data'])

# %%
df = df[['user.username','caption.text','tags','comments.count','likes.count','filter','type','created_time','user.full_name','user.id','link','location.latitude','location.longitude']]

# %%
df.rename(columns={'user.username':'user_name',
                   'caption.text':'caption_text',
                   'tags':'hashtags',
                   'comments.count':'comments_count',
                   'likes.count':'likes_count',
                   'filter':'filter',
                   'created_time':'created_time',
                   'user.full_name':'full_name',
                   'user.id':'user_id',
                   'type':'type',
                   'link':'link',
                   'location.latitude':'latitude',
                   'location.longitude':'longitude'},
          inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 13 columns):
# user_name         33 non-null object
# caption_text      33 non-null object
# hashtags          33 non-null object
# comments_count    33 non-null int64
# likes_count       33 non-null int64
# filter            33 non-null object
# type              33 non-null object
# created_time      33 non-null object
# full_name         33 non-null object
# user_id           33 non-null object
# link              33 non-null object
# latitude          23 non-null float64
# longitude         23 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 3.6+ KB

# %%
import pandas as pd
import requests
import json


from pandas.io.json import json_normalize

# %matplotlib inline


def hashtagsearch(query):
    
    client_id = '768fcf1f36c94eb08506bae0a9caffa3'
    secret = '54efcbaed7f64673bc93b4e28ca9e8b2'
    base_url = "https://api.instagram.com/v1"

    url = '{0}/tags/{1}/media/recent?client_id={2}&count=33'.format(base_url, query, client_id)

    df = json_normalize(requests.get(url).json()['data'])
    
    df = df[['user.username','caption.text','tags','comments.count','likes.count',
             'filter','type','created_time','user.full_name','user.id','link','location.latitude',
             'location.longitude']]
    
    df.rename(columns={'user.username':'user_name',
                   'caption.text':'caption_text',
                   'tags':'hashtags',
                   'comments.count':'comments_count',
                   'likes.count':'likes_count',
                   'filter':'filter',
                   'created_time':'created_time',
                   'user.full_name':'full_name',
                   'user.id':'user_id',
                   'type':'type',
                   'link':'link',
                   'location.latitude':'latitude',
                   'location.longitude':'longitude'},
          inplace=True)
    
    return df.head()

# %%
hashtagsearch('raisanosova')
# Out:
#        user_name                                       caption_text  \
# 0     delartrans  #RaisaNosova #nyc #Art #ContemporaryArt #Cambo...
# 1  alpacamuffins  #raisanosova #artist #art #gallery #les #exhib...
# 2     ksurocks88  At my lovely artists solo art exhibition #rais...
# 3    raisanosova  Peekaboo!! Come see it this Thursday-Sunday at...
# 4    raisanosova  #HoiAn, #Vietnam #Peekabooasia #raisanosova #s...
#
#                                             hashtags  comments_count  \
# 0  [lowereastside, raisanosova, art, lesgalleries...               1
# 1  [art, les, paintings, artist, fineart, portrai...               1
# 2         [lowereastside, raisanosova, peekabooasia]               0
# 3  [peekabooasia, soloexhibition, precision, les,...               2
# 4  [peekabooasia, lanterne, soloexhibition, raisa...               0
#
#    likes_count  filter   type created_time          full_name     user_id  \
# 0           19  Ludwig  image   1427573181                     1672961826
# 1           14  Normal  image   1427495996         Arielle S.   196909692
# 2           38  Normal  image   1427409820  Ksenia Svertilova   329096239
# 3           33  Normal  image   1427096262       Raisa Nosova   552586846
# 4           25  Normal  image   1426407586       Raisa Nosova   552586846
#
#                                   link   latitude  longitude
# 0  https://instagram.com/p/0yL_mfnI2x/        NaN        NaN
# 1  https://instagram.com/p/0v4xo4SVZG/  40.763010 -73.985603
# 2  https://instagram.com/p/0tUaIME2Fq/        NaN        NaN
# 3  https://instagram.com/p/0j-V-qnN7C/  40.904536 -74.186363
# 4  https://instagram.com/p/0PczJCnN57/  40.736047 -74.036018
