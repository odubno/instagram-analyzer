# %% [markdown]
# ###Objective: Create a program that scrapes Instagram data for a specified keyword and returns insightful data

# %% [markdown]
# 1) specify keyword
# 2) touch api
# 3) return data
# 4) plot data

# %% [markdown]
# ---

# %%
print 'Instagram API Documentation:', 'https://instagram.com/developer/'
print 'python-instagram repo:', 'https://github.com/Instagram/python-instagram/blob/master/README.md'
print 'project repo:', 'https://github.com/odubno/instagram_scraper'
# Out:
# Instagram API Documentation: https://instagram.com/developer/
# python-instagram repo: https://github.com/Instagram/python-instagram/blob/master/README.md
# project repo: https://github.com/odubno/instagram_scraper

# %% [markdown]
# ##Config

# %%
from instagram.client import InstagramAPI
import requests
import urllib2
import json
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
cid = 'd4ec778deaca482085b02c8556b6c2dd'
csecret = '201d0a1ed4c04ff08f82b96315c303bf'
curl = 'https://github.com/c-trl'
uri = 'https://instagram.com/developer'
url = 'https://instagram.com/oauth/authorize/?client_id='+cid+'&redirect_uri='+uri+'&response_type=token'
api = InstagramAPI(client_id=cid, client_secret=csecret)

# %%
access = 'https://instagram.com/oauth/authorize/?client_id='+cid+'&redirect_uri='+uri+'&response_type=token'
print access
# Out:
# https://instagram.com/oauth/authorize/?client_id=d4ec778deaca482085b02c8556b6c2dd&redirect_uri=https://instagram.com/developer&response_type=token

# %%
requests.get(access).url
# Out:
# u'https://instagram.com/accounts/login/?force_classic_login=&next=/oauth/authorize/%3Fclient_id%3Dd4ec778deaca482085b02c8556b6c2dd%26redirect_uri%3Dhttps%3A//instagram.com/developer%26response_type%3Dtoken'

# %%
token = '1265541089.d4ec778.3a455b41bc6643cbb2e0c406cfcce3ff' #copy/pasted from resulting URL after going to access above

# %% [markdown]
# ---

# %% [markdown]
# ###Running through Instagram's API Documentation: Useful endpoints for deciding on a query

# %% [markdown]
# ####GET /tags/search
# Search for tags by name.

# %%
#Q	A valid tag name without a leading #. (eg. snowy, nofilter)
query = raw_input('enter a hashtag you would like to search: ')
# Out:
# enter a hashtag you would like to search: mayweather

# %%
df = json_normalize(requests.get('https://api.instagram.com/v1/tags/search?q='+query+'&access_token='+token).json()['data'])

# %%
df.head(5).plot(kind='barh',
        title='Top 5 Tags Containing: '+query,
        y='media_count',
        x='name',
        figsize=(10,10))

# %%
json_normalize(requests.get('https://api.instagram.com/v1/tags/search?q='+query+'&access_token='+token).json()['data']).head()
# Out:
#    media_count                  name
# 0       573758            mayweather
# 1        42270    mayweatherpacquiao
# 2        30472    mayweathervscanelo
# 3        21383  mayweathervspacquiao
# 4        19783   mayweathervsmaidana

# %% [markdown]
# ---

# %% [markdown]
# ####GET /locations/search
# Search for a location by geographic coordinate.
#
# **returns posts with user-posted locations (check-ins)*

# %%
#DISTANCE	Default is 1000m (distance=1000), max distance is 5000.
#FACEBOOK_PLACES_ID	Returns a location mapped off of a Facebook places id. If used, a Foursquare id and lat, lng are not required.
#FOURSQUARE_ID	Returns a location mapped off of a foursquare v1 api location id. If used, you are not required to use lat and lng. Note that this method is deprecated; you should use the new foursquare IDs with V2 of their API.
#LAT	Latitude of the center search coordinate. If used, lng is required.
#LNG	Longitude of the center search coordinate. If used, lat is required.
#FOURSQUARE_V2_ID	Returns a location mapped off of a foursquare v2 api location id. If used, you are not required to use lat and lng.

#json_normalize(requests.get('https://api.instagram.com/v1/locations/search?lat=48.858844&lng=2.294351&distance=100&access_token='+token+'&count=1000').json()['data']).head()

# %% [markdown]
# ---

# %% [markdown]
# ####GET /media/search
# Search for media in a given area. The default time span is set to 5 days. The time span must not exceed 7 days. Defaults time stamps cover the last 5 days. Can return mix of image and video types.

# %%
#LAT	Latitude of the center search coordinate. If used, lng is required.
#MIN_TIMESTAMP	A unix timestamp. All media returned will be taken later than this timestamp.
#LNG	Longitude of the center search coordinate. If used, lat is required.
#MAX_TIMESTAMP	A unix timestamp. All media returned will be taken earlier than this timestamp.
#DISTANCE	Default is 1km (distance=1000), max distance is 5km.

#json_normalize(requests.get('https://api.instagram.com/v1/media/search?lat=48.858844&lng=2.294351&access_token='+token).json()['data']).head()

# %% [markdown]
# Location

# %%
#first search an area for existing location-ids
print 'https://api.instagram.com/v1/locations/search?lat=48.858844&lng=2.294351&access_token='+token

#after identifying a specific location-id, plug in to /locations/media/recent url to see recent posts from that location
print 'https://api.instagram.com/v1/locations/{location-id}/media/recent?access_token='+token
# Out:
# https://api.instagram.com/v1/locations/search?lat=48.858844&lng=2.294351&access_token=1265541089.d4ec778.3a455b41bc6643cbb2e0c406cfcce3ff
# https://api.instagram.com/v1/locations/{location-id}/media/recent?access_token=1265541089.d4ec778.3a455b41bc6643cbb2e0c406cfcce3ff

# %% [markdown]
# ---

# %% [markdown]
# ##Working with IG's API: Collecting More with Pagination

# %% [markdown]
# Calling a url's pagination data returns a next_url.  Looping this process will require using a returned next_url to call an additional next_url.  Automating retrieval of next_urls is essentially the same problem as iterating y with the equation y = x<sup>2</sup>, n times.

# %% [raw]
# def get_urls(query_url, n):
#
#       #return a next_url
#     def get(url):
#         return str(requests.get(url).json()['pagination']['next_url'])
#
#       #open list to hold urls
#     urls = list()
#
#       #handling initial url
#     url = query_url #call passed url
#     urls.append(str(url)) #add initial url to list
#
#       #handling further urls
#     for n in range(n):
#         x = get(url)
#         urls.append(str(x)) #add next_url
#         url = get(x) #replaces initial url with next_url for next turn in loop
#
#       #open list to hold data
#     results = list()
#
#       #populate df with data from urls in urls
#     for url in urls:
#         results.append(json_normalize(requests.get(url).json()['data']))
#
#       #initiate df
#     df = pd.DataFrame().append(results).reset_index().drop('index',axis=1)
#
#     return df

# %%
url = 'https://api.instagram.com/v1/tags/killdit/media/recent?count=20&client_id=d4ec778deaca482085b02c8556b6c2dd'
get_urls(url, 2)
# Out:
#    attribution  caption caption.created_time     caption.from.full_name  \
# 0         None      NaN           1430336062             LIF with the E
# 1         None      NaN           1430329302                    Michael
# 2         None      NaN           1430326720  killdit.® lifestyle brand
# 3         None      NaN           1430320471        Kristy Stuart Ashby
# 4         None      NaN           1430318674     CustomizedStickers.com
# 5         None      NaN           1430290236
# 6         None      NaN           1430286469
# 7         None      NaN           1430266959                Steve Trias
# 8         None      NaN           1430258594
# 9         None      NaN           1430251587        Founder of @killdit
# 10        None      NaN           1430251371             🔱Carpé Diem🔱
# 11        None      NaN           1430243567
# 12        None      NaN           1430241627             LIF with the E
# 13        None      NaN           1430237568         co-owner killdit.®
# 14        None      NaN           1430223298
# 15        None      NaN           1430157527
# 16        None      NaN           1430136038        Founder of @killdit
# 17        None      NaN           1430102065  killdit.® lifestyle brand
# 18        None      NaN           1430090850         co-owner killdit.®
# 19        None      NaN           1430079971               STACHE HAUS™
# 20        None      NaN           1430076902                    Caleb G
# 21        None      NaN           1430074868                  Mz.Goldie
# 22        None      NaN           1430068648                   Kristina
# 23        None      NaN           1430061205               Raul Honavar
# 24        None      NaN           1430060395                 Bboyairmax
# 25        None      NaN           1430059705        Founder of @killdit
# 26        None      NaN           1430024489                    Caleb G
# 27        None      NaN           1430019221                   Kristina
# 28        None      NaN           1430015641                 _ricagomez
# 29        None      NaN           1430006839  killdit.® lifestyle brand
# 30        None      NaN                  NaN                        NaN
# 31        None      NaN           1430004178                     Joe M.
# 32        None      NaN           1430002245                Mark Tuazon
# 33        None      NaN           1430001426                 E.j. Aguas
# 34        None      NaN           1429992057               bonnie megan
# 35        None      NaN           1429990565
# 36        None      NaN           1429983914
# 37        None      NaN           1429981937
# 38        None      NaN           1429977619  killdit.® lifestyle brand
# 39        None      NaN           1429949250               Micah Payton
# 40        None      NaN           1429761182                  Cookie 🍪
# 41        None      NaN           1429760058                    Caleb G
# 42        None      NaN           1429748230         co-owner killdit.®
# 43        None      NaN           1429746653                    Caleb G
# 44        None      NaN           1429733744               Matthew Wang
# 45        None      NaN           1429718509        Kristy Stuart Ashby
# 46        None      NaN           1429706458  killdit.® lifestyle brand
# 47        None      NaN           1429702596                  Xavier G.
# 48        None      NaN           1429667281             Allen Martinez
# 49        None      NaN           1429624483                 Life of Ai
# 50        None      NaN           1429623092           SUNRISE FESTIVAL
# 51        None      NaN           1429571222             LIF with the E
# 52        None      NaN           1429534721        Founder of @killdit
# 53        None      NaN           1429533874  killdit.® lifestyle brand
# 54        None      NaN           1429509390                DArcy Davis
# 55        None      NaN           1429508694       Shay SooPretty Likee
# 56        None      NaN           1429474480                    dennis.
# 57        None      NaN           1429469226             LIF with the E
# 58        None      NaN           1429467612           Kyle Don Tramell
# 59        None      NaN           1429444978             Stefan Rosales
#
#    caption.from.id                       caption.from.profile_picture  \
# 0          5433576  https://igcdn-photos-d-a.akamaihd.net/hphotos-...
# 1        232371835  https://igcdn-photos-g-a.akamaihd.net/hphotos-...
# 2        343340961  https://instagramimages-a.akamaihd.net/profile...
# 3        239801477  https://igcdn-photos-e-a.akamaihd.net/hphotos-...
# 4        508165085  https://igcdn-photos-f-a.akamaihd.net/hphotos-...
# 5        985465560  https://igcdn-photos-a-a.akamaihd.net/hphotos-...
# 6       1816817790  https://igcdn-photos-b-a.akamaihd.net/hphotos-...
# 7        225711219  https://igcdn-photos-c-a.akamaihd.net/hphotos-...
# 8        260182054  https://igcdn-photos-f-a.akamaihd.net/hphotos-...
# 9         13867456  https://igcdn-photos-e-a.akamaihd.net/hphotos-...
# 10       181912123  https://igcdn-photos-d-a.akamaihd.net/hphotos-...
# 11      1816817790  https://igcdn-photos-b-a.akamaihd.net/hphotos-...
# 12         5433576  https://igcdn-photos-d-a.akamaihd.net/hphotos-...
# 13       226062735  https://igcdn-photos-c-a.akamaihd.net/hphotos-...
# 14      1816817790  https://igcdn-photos-b-a.akamaihd.net/hphotos-...
# 15      1426966614  https://igcdn-photos-b-a.akamaihd.net/hphotos-...
# 16        13867456  https://igcdn-photos-e-a.akamaihd.net/hphotos-...
# 17       343340961  https://instagramimages-a.akamaihd.net/profile...
# 18       226062735  https://igcdn-photos-c-a.akamaihd.net/hphotos-...
# 19         8100441  https://instagramimages-a.akamaihd.net/profile...
# 20        24186252  https://igcdn-photos-h-a.akamaihd.net/hphotos-...
# 21       321572418  https://igcdn-photos-h-a.akamaihd.net/hphotos-...
# 22       220456004  https://igcdn-photos-h-a.akamaihd.net/hphotos-...
# 23       570887311  https://igcdn-photos-a-a.akamaihd.net/hphotos-...
# 24       197607231  https://instagramimages-a.akamaihd.net/profile...
# 25        13867456  https://igcdn-photos-e-a.akamaihd.net/hphotos-...
# 26        24186252  https://igcdn-photos-h-a.akamaihd.net/hphotos-...
# 27       220456004  https://igcdn-photos-h-a.akamaihd.net/hphotos-...
# 28       187138477  https://igcdn-photos-a-a.akamaihd.net/hphotos-...
# 29       343340961  https://instagramimages-a.akamaihd.net/profile...
# 30             NaN                                                NaN
# 31       182984872  https://igcdn-photos-a-a.akamaihd.net/hphotos-...
# 32        31399697  https://igcdn-photos-c-a.akamaihd.net/hphotos-...
# 33       320883977  https://igcdn-photos-f-a.akamaihd.net/hphotos-...
# 34       226689442  https://instagramimages-a.akamaihd.net/profile...
# 35      1816817790  https://igcdn-photos-b-a.akamaihd.net/hphotos-...
# 36      1816817790  https://igcdn-photos-b-a.akamaihd.net/hphotos-...
#
# 52  🇩🇪 BMW Driving School. #AutoX #BMW #DrivingI...               6
# 53  Be the type of person you would want to meet. ...               2
# 54  So true... I know a lot of badass champions on...               4
# 55  Me and my lil sis doin wat we do best!!! #Roll...               2
# 56  Grilldit 😉 | #killdit #foodporn #grill #vscoc...               4
# 57  Sun run over, but we were still out there doin...               8
# 58                            @reshachell220 #killdit               2
# 59  First Ride of the Year... 🚴🏾💨🍔 #specialize...               0
#
#          ...                                           users_in_photo  \
# 0        ...                                                       []
# 1        ...        [{u'position': {u'y': 0.85625, u'x': 0.8546875...
# 2        ...        [{u'position': {u'y': 0.01633987, u'x': 0.0653...
# 3        ...                                                       []
# 4        ...                                                       []
# 5        ...                                                       []
# 6        ...                                                       []
# 7        ...        [{u'position': {u'y': 0.846875, u'x': 0.467187...
# 8        ...                                                       []
# 9        ...                                                       []
# 10       ...        [{u'position': {u'y': 0.605333333, u'x': 0.518...
# 11       ...                                                       []
# 12       ...                                                       []
# 13       ...        [{u'position': {u'y': 0.197333333, u'x': 0.153...
# 14       ...                                                       []
# 15       ...        [{u'position': {u'y': 0.6375, u'x': 0.8953125}...
# 16       ...                                                       []
# 17       ...                                                       []
# 18       ...        [{u'position': {u'y': 0.944, u'x': 0.809333333...
# 19       ...        [{u'position': {u'y': 0.45277777, u'x': 0.0555...
# 20       ...        [{u'position': {u'y': 0.403125, u'x': 0.428153...
# 21       ...                                                       []
# 22       ...        [{u'position': {u'y': 0.376, u'x': 0.253333333...
# 23       ...        [{u'position': {u'y': 0.341624, u'x': 0.9375},...
# 24       ...                                                       []
# 25       ...                                                       []
# 26       ...        [{u'position': {u'y': 0.9836601, u'x': 0.93464...
# 27       ...        [{u'position': {u'y': 0.338666667, u'x': 0.622...
# 28       ...        [{u'position': {u'y': 0.7203125, u'x': 0.93464...
# 29       ...        [{u'position': {u'y': 0.872, u'x': 0.862666667...
# 30       ...        [{u'position': {u'y': 0.23466666, u'x': 0.2599...
# 31       ...        [{u'position': {u'y': 0.408, u'x': 0.498666667...
# 32       ...                                                       []
# 33       ...        [{u'position': {u'y': 0.546666667, u'x': 0.134...
# 34       ...                                                       []
# 35       ...                                                       []
# 36       ...                                                       []
# 37       ...        [{u'position': {u'y': 0.266666681, u'x': 0.782...
# 38       ...        [{u'position': {u'y': 0.777333333, u'x': 0.502...
# 39       ...                                                       []
# 40       ...                                                       []
# 41       ...                                                       []
# 42       ...        [{u'position': {u'y': 0.01633987, u'x': 0.144}...
# 43       ...        [{u'position': {u'y': 0.2578125, u'x': 0.93464...
# 44       ...                                                       []
# 45       ...                                                       []
# 46       ...                                                       []
# 47       ...                                                       []
# 48       ...                                                       []
# 49       ...        [{u'position': {u'y': 0.6703125, u'x': 0.92187...
# 50       ...        [{u'position': {u'y': 0.524, u'x': 0.526666667...
# 51       ...                                                       []
# 52       ...                                                       []
# 53       ...        [{u'position': {u'y': 0.39375, u'x': 0.7234375...
# 54       ...                                                       []
# 55       ...                                                       []
# 56       ...                                                       []
# 57       ...                                                       []
# 58       ...                                                       []
# 59       ...                                                       []
#
#    videos.low_bandwidth.height  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          480
# 4                          NaN
# 5                          NaN
# 6                          480
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         480
# 12                         NaN
# 13                         NaN
# 14                         480
# 15                         NaN
# 16                         480
# 17                         480
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         480
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# 30                         NaN
# 31                         NaN
# 32                         NaN
# 33                         NaN
# 34                         480
# 35                         480
# 36                         480
# 37                         NaN
# 38                         NaN
# 39                         NaN
# 40                         NaN
# 41                         NaN
# 42                         NaN
# 43                         NaN
# 44                         NaN
# 45                         NaN
# 46                         480
# 47                         480
# 48                         NaN
# 49                         NaN
# 50                         NaN
# 51                         NaN
# 52                         480
# 53                         NaN
# 54                         NaN
# 55                         480
# 56                         NaN
# 57                         NaN
# 58                         NaN
# 59                         NaN
#
#                              videos.low_bandwidth.url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://scontent.cdninstagram.com/hphotos-xaf1...
# 4                                                 NaN
# 5                                                 NaN
# 6   https://scontent.cdninstagram.com/hphotos-xaf1...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  https://scontent.cdninstagram.com/hphotos-xfa1...
# 12                                                NaN
# 13                                                NaN
# 14  https://scontent.cdninstagram.com/hphotos-xfa1...
# 15                                                NaN
# 16  https://scontent.cdninstagram.com/hphotos-xaf1...
# 17  https://scontent.cdninstagram.com/hphotos-xaf1...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://scontent.cdninstagram.com/hphotos-xaf1...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  https://scontent.cdninstagram.com/hphotos-xfa1...
# 35  https://scontent.cdninstagram.com/hphotos-xaf1...
# 36  https://scontent.cdninstagram.com/hphotos-xaf1...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46  https://scontent.cdninstagram.com/hphotos-xaf1...
# 47  https://scontent.cdninstagram.com/hphotos-xaf1...
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52  https://scontent.cdninstagram.com/hphotos-xfa1...
# 53                                                NaN
# 54                                                NaN
# 55  https://scontent.cdninstagram.com/hphotos-xaf1...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
#
#    videos.low_bandwidth.width  videos.low_resolution.height  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         480                           480
# 4                         NaN                           NaN
# 5                         NaN                           NaN
# 6                         480                           480
# 7                         NaN                           NaN
# 8                         NaN                           NaN
# 9                         NaN                           NaN
# 10                        NaN                           NaN
# 11                        480                           480
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        480                           480
# 15                        NaN                           NaN
# 16                        480                           480
# 17                        480                           480
# 18                        NaN                           NaN
# 19                        NaN                           NaN
# 20                        NaN                           NaN
# 21                        NaN                           NaN
# 22                        NaN                           NaN
# 23                        NaN                           NaN
# 24                        NaN                           NaN
# 25                        480                           480
# 26                        NaN                           NaN
# 27                        NaN                           NaN
# 28                        NaN                           NaN
# 29                        NaN                           NaN
# 30                        NaN                           NaN
# 31                        NaN                           NaN
# 32                        NaN                           NaN
# 33                        NaN                           NaN
# 34                        480                           480
# 35                        480                           480
# 36                        480                           480
# 37                        NaN                           NaN
# 38                        NaN                           NaN
# 39                        NaN                           NaN
# 40                        NaN                           NaN
# 41                        NaN                           NaN
# 42                        NaN                           NaN
# 43                        NaN                           NaN
# 44                        NaN                           NaN
# 45                        NaN                           NaN
# 46                        480                           480
# 47                        480                           480
# 48                        NaN                           NaN
# 49                        NaN                           NaN
# 50                        NaN                           NaN
# 51                        NaN                           NaN
# 52                        480                           480
# 53                        NaN                           NaN
# 54                        NaN                           NaN
# 55                        480                           480
# 56                        NaN                           NaN
# 57                        NaN                           NaN
# 58                        NaN                           NaN
# 59                        NaN                           NaN
#
#                             videos.low_resolution.url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://scontent.cdninstagram.com/hphotos-xaf1...
# 4                                                 NaN
# 5                                                 NaN
# 6   https://scontent.cdninstagram.com/hphotos-xaf1...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  https://scontent.cdninstagram.com/hphotos-xfa1...
# 12                                                NaN
# 13                                                NaN
# 14  https://scontent.cdninstagram.com/hphotos-xfa1...
# 15                                                NaN
# 16  https://scontent.cdninstagram.com/hphotos-xaf1...
# 17  https://scontent.cdninstagram.com/hphotos-xaf1...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://scontent.cdninstagram.com/hphotos-xaf1...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  https://scontent.cdninstagram.com/hphotos-xfa1...
# 35  https://scontent.cdninstagram.com/hphotos-xaf1...
# 36  https://scontent.cdninstagram.com/hphotos-xaf1...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46  https://scontent.cdninstagram.com/hphotos-xaf1...
# 47  https://scontent.cdninstagram.com/hphotos-xaf1...
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52  https://scontent.cdninstagram.com/hphotos-xfa1...
# 53                                                NaN
# 54                                                NaN
# 55  https://scontent.cdninstagram.com/hphotos-xaf1...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
#
#     videos.low_resolution.width  videos.standard_resolution.height  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           480                                640
# 4                           NaN                                NaN
# 5                           NaN                                NaN
# 6                           480                                640
# 7                           NaN                                NaN
# 8                           NaN                                NaN
# 9                           NaN                                NaN
# 10                          NaN                                NaN
# 11                          480                                640
# 12                          NaN                                NaN
# 13                          NaN                                NaN
# 14                          480                                640
# 15                          NaN                                NaN
# 16                          480                                640
# 17                          480                                640
# 18                          NaN                                NaN
# 19                          NaN                                NaN
# 20                          NaN                                NaN
# 21                          NaN                                NaN
# 22                          NaN                                NaN
# 23                          NaN                                NaN
# 24                          NaN                                NaN
# 25                          480                                640
# 26                          NaN                                NaN
# 27                          NaN                                NaN
# 28                          NaN                                NaN
# 29                          NaN                                NaN
# 30                          NaN                                NaN
# 31                          NaN                                NaN
# 32                          NaN                                NaN
# 33                          NaN                                NaN
# 34                          480                                640
# 35                          480                                640
# 36                          480                                640
# 37                          NaN                                NaN
# 38                          NaN                                NaN
# 39                          NaN                                NaN
# 40                          NaN                                NaN
# 41                          NaN                                NaN
# 42                          NaN                                NaN
# 43                          NaN                                NaN
# 44                          NaN                                NaN
# 45                          NaN                                NaN
# 46                          480                                640
# 47                          480                                640
# 48                          NaN                                NaN
# 49                          NaN                                NaN
# 50                          NaN                                NaN
# 51                          NaN                                NaN
# 52                          480                                640
# 53                          NaN                                NaN
# 54                          NaN                                NaN
# 55                          480                                640
# 56                          NaN                                NaN
# 57                          NaN                                NaN
# 58                          NaN                                NaN
# 59                          NaN                                NaN
#
#                        videos.standard_resolution.url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://scontent.cdninstagram.com/hphotos-xfa1...
# 4                                                 NaN
# 5                                                 NaN
# 6   https://scontent.cdninstagram.com/hphotos-xaf1...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  https://scontent.cdninstagram.com/hphotos-xaf1...
# 12                                                NaN
# 13                                                NaN
# 14  https://scontent.cdninstagram.com/hphotos-xfa1...
# 15                                                NaN
# 16  https://scontent.cdninstagram.com/hphotos-xaf1...
# 17  https://scontent.cdninstagram.com/hphotos-xaf1...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://scontent.cdninstagram.com/hphotos-xfa1...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  https://scontent.cdninstagram.com/hphotos-xfa1...
# 35  https://scontent.cdninstagram.com/hphotos-xaf1...
# 36  https://scontent.cdninstagram.com/hphotos-xaf1...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46  https://scontent.cdninstagram.com/hphotos-xfa1...
# 47  https://scontent.cdninstagram.com/hphotos-xaf1...
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52  https://scontent.cdninstagram.com/hphotos-xaf1...
# 53                                                NaN
# 54                                                NaN
# 55  https://scontent.cdninstagram.com/hphotos-xaf1...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
#
#     videos.standard_resolution.width
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                640
# 4                                NaN
# 5                                NaN
# 6                                640
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               640
# 12                               NaN
# 13                               NaN
# 14                               640
# 15                               NaN
# 16                               640
# 17                               640
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                               640
# 26                               NaN
# 27                               NaN
# 28                               NaN
# 29                               NaN
# 30                               NaN
# 31                               NaN
# 32                               NaN
# 33                               NaN
# 34                               640
# 35                               640
# 36                               640
# 37                               NaN
# 38                               NaN
# 39                               NaN
# 40                               NaN
# 41                               NaN
# 42                               NaN
# 43                               NaN
# 44                               NaN
# 45                               NaN
# 46                               640
# 47                               640
# 48                               NaN
# 49                               NaN
# 50                               NaN
# 51                               NaN
# 52                               640
# 53                               NaN
# 54                               NaN
# 55                               640
# 56                               NaN
# 57                               NaN
# 58                               NaN
# 59                               NaN
#
# [60 rows x 47 columns]

# %%
query_url = 'https://api.instagram.com/v1/tags/pacquiao/media/recent?count=20&client_id=d4ec778deaca482085b02c8556b6c2dd'

  #return a next_url
def get(url):
    return str(requests.get(url).json()['pagination']['next_url'])

  #open list to hold urls
urls = list() 

  #handling initial url
url = query_url #call passed url
urls.append(str(url)) #add initial url to list

  #handling further urls    
for n in range(2):
    x = get(url) 
    urls.append(str(x)) #add next_url
    url = get(x) #replaces initial url with next_url for next turn in loop

  #open list to hold data
results = list()

  #populate df with data from urls in urls
for url in urls:
    results.append(json_normalize(requests.get(url).json()['data']))
    
  #initiate df
df = pd.DataFrame().append(results).reset_index().drop('index',axis=1)

# %%
df.head()
# Out:
#   attribution caption.created_time    caption.from.full_name caption.from.id  \
# 0        None           1430336980                     Chris        43724625
# 1        None           1430336958   Hard Rock Cafe Medellin       292661665
# 2        None           1430336927  NirvanaEntertainmentInc.      1574334006
# 3        None           1430336925           Wilson Leonardo       269502246
# 4        None           1430336918                     Steph      1481688440
#
#                         caption.from.profile_picture caption.from.username  \
# 0  https://igcdn-photos-a-a.akamaihd.net/hphotos-...        chriscooke1966
# 1  https://igcdn-photos-e-a.akamaihd.net/hphotos-...      hardrockmedellin
# 2  https://igcdn-photos-e-a.akamaihd.net/hphotos-...      julietscastleyyc
# 3  https://igcdn-photos-h-a.akamaihd.net/hphotos-...           wilsonlsoto
# 4  https://igcdn-photos-e-a.akamaihd.net/hphotos-...          imstephyxoxo
#
#            caption.id                                       caption.text  \
# 0  974059651660794316                     #Mayweather #Pacquiao #Buzzing
# 1  974059462528207191  La pelea del siglo vivela en #HardRockMed\nEst...
# 2  974059204840955610  #Boxing #amazing #megafight #cantwait #bigfigh...
# 3  974059188028382475  Waiting to watch this #fight on #saturday and ...
# 4  974059127371580610  😂😂👊💥 hahaha #floydbelike #floyd #floydmayw...
#
#    comments.count comments.data      ...      users_in_photo  \
# 0               0            []      ...                  []
# 1               0            []      ...                  []
# 2               0            []      ...                  []
# 3               0            []      ...                  []
# 4               0            []      ...                  []
#
#   videos.low_bandwidth.height videos.low_bandwidth.url  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#    videos.low_bandwidth.width videos.low_resolution.height  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    videos.low_resolution.url  videos.low_resolution.width  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#   videos.standard_resolution.height  videos.standard_resolution.url  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#    videos.standard_resolution.width
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 46 columns]

# %%
df['comments.data'][5][0]['text']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-e294a2fbda18> in <module>()
# ----> 1 df['comments.data'][5][0]['text']
#
# IndexError: list index out of range

# %%
stage['comments.data'][44][1]['text'].encode('ascii','ignore')

# %% [markdown]
# ###Most Recent Instagram Posts:

# %%
#when you query for a specific hashtag (e.g. 'newyorkcity')
#how many likes did a post get; likes
#captions
#tags *
#total amount of comments
#user
#filter *
#type of media *
#time *
#location *
#link *

# %% [markdown]
# #To-Do List:

# %% [markdown]
# - aggregate tags and comments for sentiment analysis

# %% [markdown]
# - unpack comment data

# %% [markdown]
# - create algorithm for pipe score
