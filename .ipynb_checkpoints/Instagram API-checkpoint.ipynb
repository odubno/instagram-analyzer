# %%
import pandas as pd
import requests
import json

client_id = '768fcf1f36c94eb08506bae0a9caffa3'
secret = '54efcbaed7f64673bc93b4e28ca9e8b2'
base_url = "https://api.instagram.com/v1"
query = "newyorkcity"

url = '{0}/tags/{1}/media/recent?client_id={2}'.format(base_url, query, client_id)

r = requests.get(url)
r = r.json()

#print

# %%
r
# Out:
# {u'data': [{u'attribution': None,
#    u'caption': {u'created_time': u'1430159534',
#     u'from': {u'full_name': u'Silvia Foz',
#      u'id': u'1510978897',
#      u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/10844101_330407973834601_1101875475_a.jpg',
#      u'username': u'silviafozphoto'},
#     u'id': u'972571129652505243',
#     u'text': u'#work #weddingphotography #wedding #weddingnyc #brooklyn #brooklynwinery #bride #newyork #newyorkcity #nyc @vikmphoto @brooklynwinery'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159534',
#    u'filter': u'Normal',
#    u'id': u'972571128369048408_1510978897',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xpa1/t51.2885-15/s306x306/e15/928804_772902426161678_197630593_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xpa1/t51.2885-15/e15/928804_772902426161678_197630593_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xpa1/t51.2885-15/s150x150/e15/928804_772902426161678_197630593_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 0, u'data': []},
#    u'link': u'https://instagram.com/p/1_REnRPOtY/',
#    u'location': None,
#    u'tags': [u'weddingnyc',
#     u'weddingphotography',
#     u'newyorkcity',
#     u'newyork',
#     u'work',
#     u'bride',
#     u'brooklyn',
#     u'wedding',
#     u'brooklynwinery',
#     u'nyc'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Silvia Foz',
#     u'id': u'1510978897',
#     u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/10844101_330407973834601_1101875475_a.jpg',
#     u'username': u'silviafozphoto'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159524',
#     u'from': {u'full_name': u'NEON EDGE DUBAI',
#      u'id': u'190906948',
#      u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/10864749_947482331950544_231358525_a.jpg',
#      u'username': u'neonedge'},
#     u'id': u'972571041821783610',
#     u'text': u'Highly recommended to visit @abckitchen if you are in #manhattan. The organic food is simply divine ! And the Popcorn toffee ice cream sundae dessert says it Alllll! \U0001f60d #abckitchen #yummy #manhattan #recommended #nyc #newyorkcity #food #organic #foods'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159524',
#    u'filter': u'Amaro',
#    u'id': u'972571040076953064_190906948',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s306x306/e15/11187011_472323792933451_488430377_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/e15/11187011_472323792933451_488430377_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s150x150/e15/11187011_472323792933451_488430377_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 1,
#     u'data': [{u'full_name': u'Kelly Ann',
#       u'id': u'278674751',
#       u'profile_picture': u'https://igcdn-photos-c-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11176598_1585606071717778_2139985003_a.jpg',
#       u'username': u'charmdlife19'}]},
#    u'link': u'https://instagram.com/p/1_RDVCnnXo/',
#    u'location': {u'latitude': 40.644195785, u'longitude': -73.782304049},
#    u'tags': [u'yummy',
#     u'newyorkcity',
#     u'food',
#     u'abckitchen',
#     u'foods',
#     u'recommended',
#     u'organic',
#     u'nyc',
#     u'manhattan'],
#    u'type': u'image',
#    u'user': {u'full_name': u'NEON EDGE DUBAI',
#     u'id': u'190906948',
#     u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/10864749_947482331950544_231358525_a.jpg',
#     u'username': u'neonedge'},
#    u'users_in_photo': [{u'position': {u'x': 0.429333333, u'y': 0.313333333},
#      u'user': {u'full_name': u'ABC Kitchen',
#       u'id': u'250510156',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_250510156_75sq_1352581027.jpg',
#       u'username': u'abckitchen'}}]},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159508',
#     u'from': {u'full_name': u'Jeanette Fj\xf8rtoft',
#      u'id': u'10750893',
#      u'profile_picture': u'https://igcdn-photos-c-a.akamaihd.net/hphotos-ak-xpf1/t51.2885-19/10499103_486423281490842_1144970017_a.jpg',
#      u'username': u'jeanettefjortoft'},
#     u'id': u'972570909414914161',
#     u'text': u'Too awesome to fit in one pic!\U0001f44a Takk for tidenes tur\u2661 #ccp #CoastalCoinPockets #CarlingsNYC #nyc #newyorkcity'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159508',
#    u'filter': u'X-Pro II',
#    u'id': u'972570907787524599_10750893',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11193079_1421181364866218_1129771286_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11193079_1421181364866218_1129771286_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11193079_1421181364866218_1129771286_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 0, u'data': []},
#    u'link': u'https://instagram.com/p/1_RBZ1jfn3/',
#    u'location': None,
#    u'tags': [u'nyc',
#     u'carlingsnyc',
#     u'ccp',
#     u'coastalcoinpockets',
#     u'newyorkcity'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Jeanette Fj\xf8rtoft',
#     u'id': u'10750893',
#     u'profile_picture': u'https://igcdn-photos-c-a.akamaihd.net/hphotos-ak-xpf1/t51.2885-19/10499103_486423281490842_1144970017_a.jpg',
#     u'username': u'jeanettefjortoft'},
#    u'users_in_photo': [{u'position': {u'x': 0.91851854, u'y': 0.5546296},
#      u'user': {u'full_name': u'Maja \U0001f609',
#       u'id': u'3475660',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_3475660_75sq_1394731332.jpg',
#       u'username': u'majashuffelin'}},
#     {u'position': {u'x': 0.4287037, u'y': 0.5148148},
#      u'user': {u'full_name': u'Jeanette Fj\xf8rtoft',
#       u'id': u'10750893',
#       u'profile_picture': u'https://igcdn-photos-c-a.akamaihd.net/hphotos-ak-xpf1/t51.2885-19/10499103_486423281490842_1144970017_a.jpg',
#       u'username': u'jeanettefjortoft'}},
#     {u'position': {u'x': 0.7398148, u'y': 0.20185184},
#      u'user': {u'full_name': u'madsmh',
#       u'id': u'28843371',
#       u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xfp1/t51.2885-19/10785001_1535271330047667_674339827_a.jpg',
#       u'username': u'madsmh'}},
#     {u'position': {u'x': 0.08981481, u'y': 0.2824074},
#      u'user': {u'full_name': u'Emil',
#       u'id': u'34818608',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_34818608_75sq_1386284241.jpg',
#       u'username': u'emilstedjestad'}}]},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159506',
#     u'from': {u'full_name': u'Angel',
#      u'id': u'176193768',
#      u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11055477_810122482370303_950913741_a.jpg',
#      u'username': u'xxanxma'},
#     u'id': u'972570891113915489',
#     u'text': u'#nyc#newyork#newyorkcity#inlove#5thave#spring#hkig'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159506',
#    u'filter': u'Ludwig',
#    u'id': u'972570889394251028_176193768',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11084661_704688086320197_52030687_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11084661_704688086320197_52030687_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11084661_704688086320197_52030687_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 2,
#     u'data': [{u'full_name': u'',
#       u'id': u'9450049',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_9450049_75sq_1393005055.jpg',
#       u'username': u'dark1980'},
#      {u'full_name': u'Sandie',
#       u'id': u'1521762657',
#       u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xap1/t51.2885-19/1389762_755340364540784_1942629520_a.jpg',
#       u'username': u'mrmaksim150781'}]},
#    u'link': u'https://instagram.com/p/1_RBItOuUU/',
#    u'location': {u'latitude': 40.758625, u'longitude': -73.978133333},
#    u'tags': [u'hkig',
#     u'newyorkcity',
#     u'nyc',
#     u'newyork',
#     u'spring',
#     u'5thave',
#     u'inlove'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Angel',
#     u'id': u'176193768',
#     u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11055477_810122482370303_950913741_a.jpg',
#     u'username': u'xxanxma'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159491',
#     u'from': {u'full_name': u'',
#      u'id': u'483823799',
#      u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_483823799_75sq_1374975336.jpg',
#      u'username': u'juanes_polonia'},
#     u'id': u'972570767432310927',
#     u'text': u'By @cesarcalderonm "@Juanes || Barclays Center, NYC || cecaphoto.com || \xa9 Cesar Calder\xf3n. All rights reserved.\n\u2022\u2022\u2022\u2022\u2022\u2022\u2022\u2022\u2022\u2022\n#Juanes #colombia #parce #concert #canon_official #medellin #newyork #newyorkcity #nyc #barclayscenter #brooklyn #cecaphoto #concierto #cesarcalderonphotography #concertphotography #teamcanon #canon #canon_official #ekhymosis #rockenespa\xf1ol #picoftheday #photooftheday #band #bandphotography #music #musician #musicphotography #guitar #guitarist" via @PhotoRepost_app'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159491',
#    u'filter': u'Normal',
#    u'id': u'972570765897195816_483823799',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11191182_366105376928289_1400323204_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11191182_366105376928289_1400323204_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11191182_366105376928289_1400323204_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 2,
#     u'data': [{u'full_name': u'Rainbow Cleaning Service',
#       u'id': u'325113152',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_325113152_75sq_1369865365.jpg',
#       u'username': u'rainbowcleaningnyc'},
#      {u'full_name': u'C E S A R   C A L D E R \xd3 N',
#       u'id': u'30724645',
#       u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xap1/t51.2885-19/10706715_1466212467000720_1123684542_a.jpg',
#       u'username': u'cesarcalderonm'}]},
#    u'link': u'https://instagram.com/p/1_Q_VsO2Eo/',
#    u'location': None,
#    u'tags': [u'rockenespa\xf1ol',
#     u'concert',
#     u'newyork',
#     u'musician',
#     u'canon',
#     u'guitar',
#     u'band',
#     u'brooklyn',
#     u'ekhymosis',
#     u'teamcanon',
#     u'colombia',
#     u'nyc',
#     u'canon_official',
#     u'newyorkcity',
#     u'parce',
#     u'bandphotography',
#     u'cesarcalderonphotography',
#     u'musicphotography',
#     u'guitarist',
#     u'medellin',
#     u'picoftheday',
#     u'concierto',
#     u'music',
#     u'juanes',
#     u'cecaphoto',
#     u'concertphotography',
#     u'barclayscenter',
#     u'photooftheday'],
#    u'type': u'image',
#    u'user': {u'full_name': u'',
#     u'id': u'483823799',
#     u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_483823799_75sq_1374975336.jpg',
#     u'username': u'juanes_polonia'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159484',
#     u'from': {u'full_name': u'Connor Phelan',
#      u'id': u'21896138',
#      u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11093028_802432769827655_1718342005_a.jpg',
#      u'username': u'cophstagram'},
#     u'id': u'972570703139294431',
#     u'text': u'Liberty of statues #statueofliberty #statue #liberty #newyorkcity #ellisisland #island #libertytrickett'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159484',
#    u'filter': u'Kelvin',
#    u'id': u'972570701570625137_21896138',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11203000_678428615595812_358297875_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11203000_678428615595812_358297875_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11203000_678428615595812_358297875_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 0, u'data': []},
#    u'link': u'https://instagram.com/p/1_Q-ZyEc5x/',
#    u'location': {u'id': 212911294,
#     u'latitude': 40.689213095,
#     u'longitude': -74.044525623,
#     u'name': u'Statue of Liberty National Monument'},
#    u'tags': [u'ellisisland',
#     u'statue',
#     u'statueofliberty',
#     u'libertytrickett',
#     u'island',
#     u'liberty',
#     u'newyorkcity'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Connor Phelan',
#     u'id': u'21896138',
#     u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11093028_802432769827655_1718342005_a.jpg',
#     u'username': u'cophstagram'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159479',
#     u'from': {u'full_name': u'Photo Edits',
#      u'id': u'1746088593',
#      u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11015681_769724479779779_1253216272_a.jpg',
#      u'username': u'frolic_graffix'},
#     u'id': u'972570666936576847',
#     u'text': u'Happy Babe Ruth Day! #BabeRuthDay #babe #ruth #baberuth #mlb #baseball #bat #hit #yankees #new #york #city #newyorkcity #newyork #newyorkyankees #edit #sports #spirtsedit'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159479',
#    u'filter': u'X-Pro II',
#    u'id': u'972570665091083067_1746088593',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11193082_432561450258280_2123697726_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11193082_432561450258280_2123697726_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11193082_432561450258280_2123697726_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 2,
#     u'data': [{u'full_name': u'Mama',
#       u'id': u'562603545',
#       u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11176451_357055737838289_1374091002_a.jpg',
#       u'username': u'mama.971'},
#      {u'full_name': u'Kik:zoraiz_01',
#       u'id': u'1504480243',
#       u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xpa1/t51.2885-19/10724585_586354408156731_1781765993_a.jpg',
#       u'username': u'zuraizsaram'}]},
#    u'link': u'https://instagram.com/p/1_Q93zuCs7/',
#    u'location': None,
#    u'tags': [u'babe',
#     u'newyorkcity',
#     u'newyork',
#     u'baberuthday',
#     u'baseball',
#     u'york',
#     u'hit',
#     u'mlb',
#     u'city',
#     u'bat',
#     u'newyorkyankees',
#     u'edit',
#     u'sports',
#     u'baberuth',
#     u'new',
#     u'ruth',
#     u'spirtsedit',
#     u'yankees'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Photo Edits',
#     u'id': u'1746088593',
#     u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11015681_769724479779779_1253216272_a.jpg',
#     u'username': u'frolic_graffix'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159476',
#     u'from': {u'full_name': u'',
#      u'id': u'25539722',
#      u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/10919215_780950288651785_1273825761_a.jpg',
#      u'username': u'sammywall'},
#     u'id': u'972570642795318277',
#     u'text': u'That old #classic view on my #flight to #NewYorkCity #NYC #thebigapple'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159476',
#    u'filter': u'Ludwig',
#    u'id': u'972570641235037895_25539722',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s306x306/e15/11191379_878312308896393_1768056513_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/e15/11191379_878312308896393_1768056513_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s150x150/e15/11191379_878312308896393_1768056513_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 1,
#     u'data': [{u'full_name': u'Briggette Gazzo',
#       u'id': u'1735529996',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11049142_1058745070809101_1218258156_a.jpg',
#       u'username': u'brigidgazzo'}]},
#    u'link': u'https://instagram.com/p/1_Q9hlyc7H/',
#    u'location': None,
#    u'tags': [u'thebigapple', u'nyc', u'flight', u'newyorkcity', u'classic'],
#    u'type': u'image',
#    u'user': {u'full_name': u'',
#     u'id': u'25539722',
#     u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/10919215_780950288651785_1273825761_a.jpg',
#     u'username': u'sammywall'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159467',
#     u'from': {u'full_name': u'',
#      u'id': u'2121615957',
#      u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/anonymousUser.jpg',
#      u'username': u'gilpkmenm'},
#     u'id': u'972570561489074238',
#     u'text': u'Shipping Worldwide For more info, please contact \u2605 Whatsapp: +8613566347511 Wechat:juby1688  #loewe#patience#men#rates#newyorkcity#lifequotes#muscles#likeforlike#lovers#man#langeweile#mygirls#muse#prima#not#power#murmer#posey#momentos#recuerdos#polishboy#reseller#noshame#missingyou#recovery#luckygirl#mexicocity#nuts#lux#otp'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159467',
#    u'filter': u'Normal',
#    u'id': u'972570559769409549_2121615957',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s306x306/e15/11190131_1405085856480121_1007657376_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/e15/11190131_1405085856480121_1007657376_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s150x150/e15/11190131_1405085856480121_1007657376_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 9,
#     u'data': [{u'full_name': u'Beth Thomas Cohen',
#       u'id': u'13725113',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098573_639102952900357_681328859_a.jpg',
#       u'username': u'beththomascohen'},
#      {u'full_name': u'',
#       u'id': u'188543218',
#       u'profile_picture': u'https://igcdn-photos-g-a.akamaihd.net/hphotos-ak-xpf1/t51.2885-19/1660811_861414363923342_2019167016_a.jpg',
#       u'username': u'ambeezy_801'},
#      {u'full_name': u'Ami G Jabbie',
#       u'id': u'175301717',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11184481_434495383377229_166100107_a.jpg',
#       u'username': u'amiinataag'},
#      {u'full_name': u'Nicole Noonan',
#       u'id': u'3859055',
#       u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098539_848333091906883_976958152_a.jpg',
#       u'username': u'nicolexnoonan'}]},
#    u'link': u'https://instagram.com/p/1_Q8VuDvgN/',
#    u'location': None,
#    u'tags': [u'otp',
#     u'momentos',
#     u'muscles',
#     u'newyorkcity',
#     u'murmer',
#     u'lifequotes',
#     u'men',
#     u'muse',
#     u'luckygirl',
#     u'patience',
#     u'noshame',
#     u'recuerdos',
#     u'langeweile',
#     u'not',
#     u'mygirls',
#     u'man',
#     u'lovers',
#     u'prima',
#     u'polishboy',
#     u'reseller',
#     u'posey',
#     u'lux',
#     u'recovery',
#     u'nuts',
#     u'power',
#     u'loewe',
#     u'missingyou',
#     u'rates',
#     u'likeforlike',
#     u'mexicocity'],
#    u'type': u'image',
#    u'user': {u'full_name': u'',
#     u'id': u'2121615957',
#     u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/anonymousUser.jpg',
#     u'username': u'gilpkmenm'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159425',
#     u'from': {u'full_name': u'Yana Lykhman',
#      u'id': u'1177102',
#      u'profile_picture': u'https://igcdn-photos-g-a.akamaihd.net/hphotos-ak-xpa1/t51.2885-19/10632512_764891566902534_1898161092_a.jpg',
#      u'username': u'cocosh'},
#     u'id': u'972570211349749432',
#     u'text': u'Ghost city \U0001f47b'},
#    u'comments': {u'count': 1,
#     u'data': [{u'created_time': u'1430159473',
#       u'from': {u'full_name': u'Yana Lykhman',
#        u'id': u'1177102',
#        u'profile_picture': u'https://igcdn-photos-g-a.akamaihd.net/hphotos-ak-xpa1/t51.2885-19/10632512_764891566902534_1898161092_a.jpg',
#        u'username': u'cocosh'},
#       u'id': u'972570615638712018',
#       u'text': u'#NYC #newyork #newyorkcity #citylife #manhattan #nyclife'}]},
#    u'created_time': u'1430159425',
#    u'filter': u'Normal',
#    u'id': u'972570209831411069_1177102',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s306x306/e15/11201675_807839452619023_60946882_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/e15/11201675_807839452619023_60946882_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s150x150/e15/11201675_807839452619023_60946882_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 1,
#     u'data': [{u'full_name': u'',
#       u'id': u'9450049',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_9450049_75sq_1393005055.jpg',
#       u'username': u'dark1980'}]},
#    u'link': u'https://instagram.com/p/1_Q3P0IN19/',
#    u'location': {u'id': 29029804,
#     u'latitude': 40.757591228,
#     u'longitude': -74.00116131,
#     u'name': u'Javits Center'},
#    u'tags': [u'nyclife',
#     u'newyorkcity',
#     u'newyork',
#     u'nyc',
#     u'manhattan',
#     u'citylife'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Yana Lykhman',
#     u'id': u'1177102',
#     u'profile_picture': u'https://igcdn-photos-g-a.akamaihd.net/hphotos-ak-xpa1/t51.2885-19/10632512_764891566902534_1898161092_a.jpg',
#     u'username': u'cocosh'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159422',
#     u'from': {u'full_name': u'I love you Solangel \U0001f60d\u2764\U0001f451',
#      u'id': u'52111920',
#      u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11176420_365278310346755_887122612_a.jpg',
#      u'username': u'ur_li0ness'},
#     u'id': u'972570186510894687',
#     u'text': u'Another shot from yesterday.  I was in love with the scenery.  #manhattanbridge #brooklynheightspromenade #brooklynpiers #newyorkcity #nyc #brooklynheights #dumbo #ilovenewyork'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159422',
#    u'filter': u'Normal',
#    u'id': u'972570184975779173_52111920',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s306x306/e15/11189666_1409921922662669_1504301433_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/e15/11189666_1409921922662669_1504301433_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s150x150/e15/11189666_1409921922662669_1504301433_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 9,
#     u'data': [{u'full_name': u'Daniel Targaryen',
#       u'id': u'224674912',
#       u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11176218_1135216693170601_489881511_a.jpg',
#       u'username': u'therealdannydarko'},
#      {u'full_name': u'Beth Thomas Cohen',
#       u'id': u'13725113',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098573_639102952900357_681328859_a.jpg',
#       u'username': u'beththomascohen'},
#      {u'full_name': u'Feli \U0001f48b',
#       u'id': u'51460531',
#       u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11094507_453593294803160_1011233415_a.jpg',
#       u'username': u'miss_lopez6'},
#      {u'full_name': u'Golden Girl',
#       u'id': u'44794527',
#       u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11008124_389333747916807_750597574_a.jpg',
#       u'username': u'kleluv'}]},
#    u'link': u'https://instagram.com/p/1_Q24qngVl/',
#    u'location': None,
#    u'tags': [u'newyorkcity',
#     u'brooklynheightspromenade',
#     u'brooklynpiers',
#     u'manhattanbridge',
#     u'ilovenewyork',
#     u'brooklynheights',
#     u'nyc',
#     u'dumbo'],
#    u'type': u'image',
#    u'user': {u'full_name': u'I love you Solangel \U0001f60d\u2764\U0001f451',
#     u'id': u'52111920',
#     u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11176420_365278310346755_887122612_a.jpg',
#     u'username': u'ur_li0ness'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159417',
#     u'from': {u'full_name': u"Sara D'Itri",
#      u'id': u'1315343209',
#      u'profile_picture': u'https://igcdn-photos-e-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11111341_672800159496356_1344533593_a.jpg',
#      u'username': u'mixer_1928'},
#     u'id': u'972570145441590150',
#     u'text': u'Okay, Poi Dicono "Sei Grassa" "Sei Brutta", Ma Cosa Dite Non Vi Vergognate!? LEI \xc8 PERFETTA, STA BENISSIMO,  E LE VOSTRE CRITICHE SVANIRANNO, JESY \xc8 UNO SPETTACOLO DELLA NATURA, E IO LA AMO! I LOVE YOU BABY\U0001f495\U0001f495\U0001f495 @jesymix14 \U0001f495\U0001f495 #life #live #livemylifetothefullest #JesyMix14 #LittleMix #Tour2015 #Salute #Towers #DNA #Theseforwalls #GoodEnough #Likelikelike #LikeForLike #SpamforSpam #FollowForFollow #LiveMyLife #instalove #MiamiBeach #NewYorkCity #BostonCity #Facebook #twittermirror #respect #Instangram #respectforthegirls #shesbeautiful #ILoveHer! \U0001f495\U0001f495'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159417',
#    u'filter': u'Normal',
#    u'id': u'972570143411546505_1315343209',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11192973_573729919436241_1374773743_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11192973_573729919436241_1374773743_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11192973_573729919436241_1374773743_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 4,
#     u'data': [{u'full_name': u"Sara D'Itri",
#       u'id': u'1315343209',
#       u'profile_picture': u'https://igcdn-photos-e-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11111341_672800159496356_1344533593_a.jpg',
#       u'username': u'mixer_1928'},
#      {u'full_name': u'Beth Thomas Cohen',
#       u'id': u'13725113',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098573_639102952900357_681328859_a.jpg',
#       u'username': u'beththomascohen'},
#      {u'full_name': u'Miro',
#       u'id': u'1028017893',
#       u'profile_picture': u'https://igcdn-photos-g-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11078881_1571501536437870_2140477867_a.jpg',
#       u'username': u'miro_bb'},
#      {u'full_name': u'Pierre Charles de Faverges',
#       u'id': u'558854182',
#       u'profile_picture': u'https://igcdn-photos-c-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/10899317_842021445841786_2039785701_a.jpg',
#       u'username': u'charliethebananasking'}]},
#    u'link': u'https://instagram.com/p/1_Q2R9MimJ/',
#    u'location': None,
#    u'tags': [u'life',
#     u'respectforthegirls',
#     u'bostoncity',
#     u'newyorkcity',
#     u'towers',
#     u'goodenough',
#     u'instalove',
#     u'littlemix',
#     u'spamforspam',
#     u'iloveher',
#     u'facebook',
#     u'respect',
#     u'twittermirror',
#     u'dna',
#     u'jesymix14',
#     u'shesbeautiful',
#     u'livemylife',
#     u'live',
#     u'tour2015',
#     u'likelikelike',
#     u'followforfollow',
#     u'instangram',
#     u'likeforlike',
#     u'miamibeach',
#     u'theseforwalls',
#     u'livemylifetothefullest',
#     u'salute'],
#    u'type': u'image',
#    u'user': {u'full_name': u"Sara D'Itri",
#     u'id': u'1315343209',
#     u'profile_picture': u'https://igcdn-photos-e-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11111341_672800159496356_1344533593_a.jpg',
#     u'username': u'mixer_1928'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159404',
#     u'from': {u'full_name': u'YslDayParty NYC',
#      u'id': u'1831870879',
#      u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xpa1/t51.2885-19/928679_1398308067157272_440619105_a.jpg',
#      u'username': u'ysldayparty'},
#     u'id': u'972570033073799697',
#     u'text': u'Saturday, May 9th \u2022 #YSLDayParty Presents a Special #MothersDayWeekend Event \u2022 2-4-1 Drinks from 4pm till 6pm \u2022 Free Massages for the ladies, Courtesy of @travelingspa \u2022 4pm - 10pm \u2022 Music by: DJ Mike Neezy, Ontrackdisco, DJ Will, DJ Novocaine & DJ Boogie \u2022 ADV Tixs $20 \u2022 Taurusseason \u2649\ufe0f \u2022 May Bdays Contact Me \u2022 Text/Call: 917.370.4926 or click link in bio #tdgroupevents \U0001f4ab\U0001f4a5\U0001f4f7'},
#    u'comments': {u'count': 1,
#     u'data': [{u'created_time': u'1430159445',
#       u'from': {u'full_name': u'YslDayParty NYC',
#        u'id': u'1831870879',
#        u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xpa1/t51.2885-19/928679_1398308067157272_440619105_a.jpg',
#        u'username': u'ysldayparty'},
#       u'id': u'972570379464589873',
#       u'text': u'#balleralert #bet #diddy #Ciaa #moneyandviolence #lhhny #beehive #bossip #viproom #livonsunday #Got #Breakfestclub #power105 #hot97 #nas #NycNightLife  #NEwyork #CT #NJ #NewJersey #7Days7Nights #AllTheParties #Dusse #Ciroc #viproom #lifestyle #newyorkcity'}]},
#    u'created_time': u'1430159404',
#    u'filter': u'Normal',
#    u'id': u'972570031429632231_1831870879',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11189683_1639678792917924_186650120_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11189683_1639678792917924_186650120_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11189683_1639678792917924_186650120_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 2,
#     u'data': [{u'full_name': u'cyncity218',
#       u'id': u'2701616',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11137982_851922994896821_1746176373_a.jpg',
#       u'username': u'cyncity218'},
#      {u'full_name': u'Beth Thomas Cohen',
#       u'id': u'13725113',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098573_639102952900357_681328859_a.jpg',
#       u'username': u'beththomascohen'}]},
#    u'link': u'https://instagram.com/p/1_Q0pqjcDn/',
#    u'location': None,
#    u'tags': [u'7days7nights',
#     u'lhhny',
#     u'newyorkcity',
#     u'ciaa',
#     u'newyork',
#     u'nycnightlife',
#     u'hot97',
#     u'ciroc',
#     u'livonsunday',
#     u'diddy',
#     u'tdgroupevents',
#     u'ct',
#     u'mothersdayweekend',
#     u'nj',
#     u'alltheparties',
#     u'lifestyle',
#     u'newjersey',
#     u'beehive',
#     u'viproom',
#     u'ysldayparty',
#     u'bossip',
#     u'moneyandviolence',
#     u'nas',
#     u'power105',
#     u'balleralert',
#     u'got',
#     u'dusse',
#     u'breakfestclub',
#     u'bet'],
#    u'type': u'image',
#    u'user': {u'full_name': u'YslDayParty NYC',
#     u'id': u'1831870879',
#     u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xpa1/t51.2885-19/928679_1398308067157272_440619105_a.jpg',
#     u'username': u'ysldayparty'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159402',
#     u'from': {u'full_name': u'\u2705 Real Madrid',
#      u'id': u'486127609',
#      u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11055825_651828788296217_534829523_a.jpg',
#      u'username': u'monsterfaisal'},
#     u'id': u'972570018244511892',
#     u'text': u'\U0001f534\n#NewYorkCity \n#MANHATTAN'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159402',
#    u'filter': u'Sierra',
#    u'id': u'972570015979587952_486127609',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xap1/t51.2885-15/s306x306/e15/10431896_423741627806988_866722901_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xap1/t51.2885-15/e15/10431896_423741627806988_866722901_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xap1/t51.2885-15/s150x150/e15/10431896_423741627806988_866722901_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 6,
#     u'data': [{u'full_name': u'King D Royalty',
#       u'id': u'222325616',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_222325616_75sq_1373668519.jpg',
#       u'username': u'kingdroyalty'},
#      {u'full_name': u'Beth Thomas Cohen',
#       u'id': u'13725113',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098573_639102952900357_681328859_a.jpg',
#       u'username': u'beththomascohen'},
#      {u'full_name': u'\u0634\u0645\u0633\u0629 \u0628\u0646\u062a \u0646\u0627\u0635\u0631',
#       u'id': u'215017167',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11176425_1582249845358333_1152691781_a.jpg',
#       u'username': u'shamsaalmatrooshi'},
#      {u'full_name': u'AME',
#       u'id': u'253590031',
#       u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11186849_1044359955594167_1249885840_a.jpg',
#       u'username': u'al_i5'}]},
#    u'link': u'https://instagram.com/p/1_Q0bRqMlw/',
#    u'location': {u'id': 1543399,
#     u'latitude': 40.765478,
#     u'longitude': -73.954189,
#     u'name': u'Hospital for Special Surgery'},
#    u'tags': [u'newyorkcity', u'manhattan'],
#    u'type': u'image',
#    u'user': {u'full_name': u'\u2705 Real Madrid',
#     u'id': u'486127609',
#     u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11055825_651828788296217_534829523_a.jpg',
#     u'username': u'monsterfaisal'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159394',
#     u'from': {u'full_name': u'Fitness & Nutrition \U0001f31e BK, NY',
#      u'id': u'988054911',
#      u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xpf1/t51.2885-19/10584814_691864267552481_694431630_a.jpg',
#      u'username': u'k_fitty'},
#     u'id': u'972569952052363729',
#     u'text': u"\u25b6\ufe0f Don't forget to look up \U0001f4463 hours to kill means venturing around the city that turned into a 2 mile walk to Bryant park {instead of going home and sleeping like a bum per my usual self}. Stop being lazy, take advantage of the time you have and get up and explore \U0001f44a\U0001f495\U0001f306 #latergram #getup #getout"},
#    u'comments': {u'count': 1,
#     u'data': [{u'created_time': u'1430159457',
#       u'from': {u'full_name': u'Fitness & Nutrition \U0001f31e BK, NY',
#        u'id': u'988054911',
#        u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xpf1/t51.2885-19/10584814_691864267552481_694431630_a.jpg',
#        u'username': u'k_fitty'},
#       u'id': u'972570479016329722',
#       u'text': u'#stopsleeping #getup #getout #getactive #explore #adventure #newyork #newyorkcity #NYC #city #empirestate #lifestyle #walk #exercise #fitness #happy #healthy #beautiful #life'}]},
#    u'created_time': u'1430159394',
#    u'filter': u'Normal',
#    u'id': u'972569950324310580_988054911',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s306x306/e15/11195795_1640772949485263_977540215_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/e15/11195795_1640772949485263_977540215_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s150x150/e15/11195795_1640772949485263_977540215_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 2,
#     u'data': [{u'full_name': u'Beth Thomas Cohen',
#       u'id': u'13725113',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098573_639102952900357_681328859_a.jpg',
#       u'username': u'beththomascohen'},
#      {u'full_name': u'Chad Gartner',
#       u'id': u'1804061737',
#       u'profile_picture': u'https://igcdn-photos-c-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11184699_569512923190570_906842707_a.jpg',
#       u'username': u'the.adventure.journal'}]},
#    u'link': u'https://instagram.com/p/1_QzeITMI0/',
#    u'location': None,
#    u'tags': [u'beautiful',
#     u'life',
#     u'newyorkcity',
#     u'newyork',
#     u'walk',
#     u'explore',
#     u'getactive',
#     u'adventure',
#     u'empirestate',
#     u'getup',
#     u'city',
#     u'lifestyle',
#     u'getout',
#     u'healthy',
#     u'stopsleeping',
#     u'latergram',
#     u'fitness',
#     u'nyc',
#     u'exercise',
#     u'happy'],
#    u'type': u'video',
#    u'user': {u'full_name': u'Fitness & Nutrition \U0001f31e BK, NY',
#     u'id': u'988054911',
#     u'profile_picture': u'https://igcdn-photos-b-a.akamaihd.net/hphotos-ak-xpf1/t51.2885-19/10584814_691864267552481_694431630_a.jpg',
#     u'username': u'k_fitty'},
#    u'users_in_photo': [],
#    u'videos': {u'low_bandwidth': {u'height': 480,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t50.2886-16/11200204_755547784544373_758524843_s.mp4',
#      u'width': 480},
#     u'low_resolution': {u'height': 480,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t50.2886-16/11200204_755547784544373_758524843_s.mp4',
#      u'width': 480},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t50.2886-16/11175595_855631824501936_151472259_n.mp4',
#      u'width': 640}}},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159391',
#     u'from': {u'full_name': u'Andy Sheffield \xa9',
#      u'id': u'6911443',
#      u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11186893_386794651503688_646516479_a.jpg',
#      u'username': u'cureforthecommon'},
#     u'id': u'972569930834022956',
#     u'text': u'If we work together, all WET PAINT signs could say T PAIN @thefatjewish'},
#    u'comments': {u'count': 1,
#     u'data': [{u'created_time': u'1430159480',
#       u'from': {u'full_name': u'Andy Sheffield \xa9',
#        u'id': u'6911443',
#        u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11186893_386794651503688_646516479_a.jpg',
#        u'username': u'cureforthecommon'},
#       u'id': u'972570672093368944',
#       u'text': u'#iphone #iphonography #iphoneography #newyorkcity #newyork #manhattan #lol #tpain #subway #funny #best #igdaily #boutthatlife #cureforthecommon'}]},
#    u'created_time': u'1430159391',
#    u'filter': u'Brannan',
#    u'id': u'972569927948341697_6911443',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11176224_1575059079434658_1872645644_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11176224_1575059079434658_1872645644_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11176224_1575059079434658_1872645644_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 0, u'data': []},
#    u'link': u'https://instagram.com/p/1_QzJSlpHB/',
#    u'location': {u'latitude': 40.750897295, u'longitude': -74.005941515},
#    u'tags': [u'cureforthecommon',
#     u'funny',
#     u'lol',
#     u'newyorkcity',
#     u'newyork',
#     u'iphoneography',
#     u'subway',
#     u'boutthatlife',
#     u'igdaily',
#     u'tpain',
#     u'iphonography',
#     u'manhattan',
#     u'best',
#     u'iphone'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Andy Sheffield \xa9',
#     u'id': u'6911443',
#     u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11186893_386794651503688_646516479_a.jpg',
#     u'username': u'cureforthecommon'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159379',
#     u'from': {u'full_name': u'Red Cole Photo',
#      u'id': u'330944598',
#      u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/10932482_443300682490437_965926167_a.jpg',
#      u'username': u'redcolephoto'},
#     u'id': u'972569828076805172',
#     u'text': u'Beautiful necklace by @whimsyartisan, Model @ronnieblair #etsy #handmade #vintage #newyork #newyorkcity #nyc #model #hair #jewelry #etsyshop #madeinusa #crafted #necklace #redcolephoto'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159379',
#    u'filter': u'Normal',
#    u'id': u'972569826508135929_330944598',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s306x306/e15/11190263_968864869813932_1764064884_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/e15/11190263_968864869813932_1764064884_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s150x150/e15/11190263_968864869813932_1764064884_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 5,
#     u'data': [{u'full_name': u'Beth Thomas Cohen',
#       u'id': u'13725113',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098573_639102952900357_681328859_a.jpg',
#       u'username': u'beththomascohen'},
#      {u'full_name': u'Stephanie Nagle',
#       u'id': u'340610',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_340610_75sq_1383312916.jpg',
#       u'username': u'snagleee'},
#      {u'full_name': u'',
#       u'id': u'1692598037',
#       u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11176536_430085383819115_1709017104_a.jpg',
#       u'username': u'remmy1221'},
#      {u'full_name': u'Boost Your IG-Like Count',
#       u'id': u'1078043633',
#       u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/10859936_723529261071135_712162396_a.jpg',
#       u'username': u'numbers.baby'}]},
#    u'link': u'https://instagram.com/p/1_Qxq0R935/',
#    u'location': None,
#    u'tags': [u'etsyshop',
#     u'newyorkcity',
#     u'newyork',
#     u'vintage',
#     u'handmade',
#     u'madeinusa',
#     u'hair',
#     u'crafted',
#     u'necklace',
#     u'nyc',
#     u'model',
#     u'etsy',
#     u'redcolephoto',
#     u'jewelry'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Red Cole Photo',
#     u'id': u'330944598',
#     u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/10932482_443300682490437_965926167_a.jpg',
#     u'username': u'redcolephoto'},
#    u'users_in_photo': [{u'position': {u'x': 0.584375, u'y': 0.4984375},
#      u'user': {u'full_name': u'ronnieblair',
#       u'id': u'48069006',
#       u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xap1/t51.2885-19/925332_1483478571923339_2004370233_a.jpg',
#       u'username': u'ronnieblair'}},
#     {u'position': {u'x': 0.9171875, u'y': 0.08125},
#      u'user': {u'full_name': u'Cole Sigmon',
#       u'id': u'22473857',
#       u'profile_picture': u'https://igcdn-photos-e-a.akamaihd.net/hphotos-ak-xpa1/t51.2885-19/1538368_809481982418892_409505533_a.jpg',
#       u'username': u'colesigmon'}},
#     {u'position': {u'x': 0.453125, u'y': 0.6328125},
#      u'user': {u'full_name': u'Whimsy Artisan',
#       u'id': u'2056000451',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/10919329_849763148392221_1724441437_a.jpg',
#       u'username': u'whimsyartisan'}}]},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159358',
#     u'from': {u'full_name': u'\u2728Camila\u2728',
#      u'id': u'1547903567',
#      u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11116919_707261089403195_50314103_a.jpg',
#      u'username': u'cami_arvallo'},
#     u'id': u'972569652107919724',
#     u'text': u'\U0001f309Brooklyn Bridge\U0001f309 #newyork #newyorkcity #nyc #unitedstates #travel #brooklynbridge'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159358',
#    u'filter': u'Mayfair',
#    u'id': u'972569648978969558_1547903567',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/10852900_1430002033982443_301899841_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/10852900_1430002033982443_301899841_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/10852900_1430002033982443_301899841_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 3,
#     u'data': [{u'full_name': u'Beth Thomas Cohen',
#       u'id': u'13725113',
#       u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11098573_639102952900357_681328859_a.jpg',
#       u'username': u'beththomascohen'},
#      {u'full_name': u'Agus',
#       u'id': u'1724908588',
#       u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11024338_333090033554635_880777440_a.jpg',
#       u'username': u'agusdavila4'},
#      {u'full_name': u'Rick / Dresden - Germany \U0001f1e9\U0001f1ea',
#       u'id': u'455520757',
#       u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11176297_103579813307439_795420666_a.jpg',
#       u'username': u'dresden_rick'}]},
#    u'link': u'https://instagram.com/p/1_QvFet8PW/',
#    u'location': None,
#    u'tags': [u'brooklynbridge',
#     u'newyorkcity',
#     u'newyork',
#     u'nyc',
#     u'travel',
#     u'unitedstates'],
#    u'type': u'image',
#    u'user': {u'full_name': u'\u2728Camila\u2728',
#     u'id': u'1547903567',
#     u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11116919_707261089403195_50314103_a.jpg',
#     u'username': u'cami_arvallo'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159356',
#     u'from': {u'full_name': u'Quinn Kantner',
#      u'id': u'1817445413',
#      u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11142923_400119380167829_863392711_a.jpg',
#      u'username': u'quinnsquirks'},
#     u'id': u'972569629774216087',
#     u'text': u'A new blog post is FINALLY up! Check it out of me exploring NYC on my senior class trip! Link is in my bio :)'},
#    u'comments': {u'count': 1,
#     u'data': [{u'created_time': u'1430159429',
#       u'from': {u'full_name': u'Quinn Kantner',
#        u'id': u'1817445413',
#        u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11142923_400119380167829_863392711_a.jpg',
#        u'username': u'quinnsquirks'},
#       u'id': u'972570246915718097',
#       u'text': u'#fashion #fashionblogger #blog #blogger #fashionblog #newyork #newyorkcity #nyc #michaelkors #jcrew #jcrewfactory #converse #ae #americaneagle #quinn #quinnsquirks #gap #express #style'}]},
#    u'created_time': u'1430159356',
#    u'filter': u'Normal',
#    u'id': u'972569627836447185_1817445413',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s306x306/e15/11203317_994284977249078_708312554_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/e15/11203317_994284977249078_708312554_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xaf1/t51.2885-15/s150x150/e15/11203317_994284977249078_708312554_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 0, u'data': []},
#    u'link': u'https://instagram.com/p/1_QuxyhnnR/',
#    u'location': None,
#    u'tags': [u'fashion',
#     u'ae',
#     u'newyorkcity',
#     u'newyork',
#     u'blogger',
#     u'converse',
#     u'gap',
#     u'quinn',
#     u'quinnsquirks',
#     u'style',
#     u'americaneagle',
#     u'jcrew',
#     u'blog',
#     u'jcrewfactory',
#     u'express',
#     u'nyc',
#     u'fashionblog',
#     u'fashionblogger',
#     u'michaelkors'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Quinn Kantner',
#     u'id': u'1817445413',
#     u'profile_picture': u'https://igcdn-photos-f-a.akamaihd.net/hphotos-ak-xfa1/t51.2885-19/11142923_400119380167829_863392711_a.jpg',
#     u'username': u'quinnsquirks'},
#    u'users_in_photo': []},
#   {u'attribution': None,
#    u'caption': {u'created_time': u'1430159348',
#     u'from': {u'full_name': u'Paul Walker',
#      u'id': u'216814',
#      u'profile_picture': u'https://igcdn-photos-g-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11111377_1646047822282166_1190045236_a.jpg',
#      u'username': u'paulfredaldous'},
#     u'id': u'972569566886256200',
#     u'text': u'#empirestatebuilding #nyc #newyork #newyorkcity #manhattan #rockefeller @rockcenternyc #topoftherock'},
#    u'comments': {u'count': 0, u'data': []},
#    u'created_time': u'1430159348',
#    u'filter': u'Normal',
#    u'id': u'972569565158202500_216814',
#    u'images': {u'low_resolution': {u'height': 306,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s306x306/e15/11203328_1595775607344966_2081611421_n.jpg',
#      u'width': 306},
#     u'standard_resolution': {u'height': 640,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/e15/11203328_1595775607344966_2081611421_n.jpg',
#      u'width': 640},
#     u'thumbnail': {u'height': 150,
#      u'url': u'https://scontent.cdninstagram.com/hphotos-xfa1/t51.2885-15/s150x150/e15/11203328_1595775607344966_2081611421_n.jpg',
#      u'width': 150}},
#    u'likes': {u'count': 6,
#     u'data': [{u'full_name': u"Andy Freakin' Lezzo",
#       u'id': u'4014472',
#       u'profile_picture': u'https://igcdn-photos-d-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11092978_800812320004203_1086925384_a.jpg',
#       u'username': u'andylezzo'},
#      {u'full_name': u'Stark',
#       u'id': u'178702081',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_178702081_75sq_1393614141.jpg',
#       u'username': u'starkcarpet'},
#      {u'full_name': u'Rick / Dresden - Germany \U0001f1e9\U0001f1ea',
#       u'id': u'455520757',
#       u'profile_picture': u'https://igcdn-photos-h-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11176297_103579813307439_795420666_a.jpg',
#       u'username': u'dresden_rick'},
#      {u'full_name': u'',
#       u'id': u'12474727',
#       u'profile_picture': u'https://instagramimages-a.akamaihd.net/profiles/profile_12474727_75sq_1340920517.jpg',
#       u'username': u'chrisski'}]},
#    u'link': u'https://instagram.com/p/1_Qt3anFyE/',
#    u'location': {u'latitude': 53.45113558, u'longitude': -2.380013034},
#    u'tags': [u'topoftherock',
#     u'empirestatebuilding',
#     u'newyorkcity',
#     u'newyork',
#     u'nyc',
#     u'rockefeller',
#     u'manhattan'],
#    u'type': u'image',
#    u'user': {u'full_name': u'Paul Walker',
#     u'id': u'216814',
#     u'profile_picture': u'https://igcdn-photos-g-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/11111377_1646047822282166_1190045236_a.jpg',
#     u'username': u'paulfredaldous'},
#    u'users_in_photo': []}],
#  u'meta': {u'code': 200},
#  u'pagination': {u'deprecation_warning': u'next_max_id and min_id are deprecated for this endpoint; use min_tag_id and max_tag_id instead',
#   u'min_tag_id': u'972571128369048408',
#   u'next_max_id': u'972569098876100211',
#   u'next_max_tag_id': u'972569098876100211',
#   u'next_min_id': u'972571128369048408',
#   u'next_url': u'https://api.instagram.com/v1/tags/newyorkcity/media/recent?client_id=768fcf1f36c94eb08506bae0a9caffa3&max_tag_id=972569098876100211'}}

# %%
df = pd.DataFrame(r['data'])

# %%
df['text'] = [x['text'] for x in df.caption]

# %%
df['caption'][1]
# Out:
# {u'created_time': u'1430159524',
#  u'from': {u'full_name': u'NEON EDGE DUBAI',
#   u'id': u'190906948',
#   u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xaf1/t51.2885-19/10864749_947482331950544_231358525_a.jpg',
#   u'username': u'neonedge'},
#  u'id': u'972571041821783610',
#  u'text': u'Highly recommended to visit @abckitchen if you are in #manhattan. The organic food is simply divine ! And the Popcorn toffee ice cream sundae dessert says it Alllll! \U0001f60d #abckitchen #yummy #manhattan #recommended #nyc #newyorkcity #food #organic #foods'}

# %%
df.head()
# Out:
#   attribution                                            caption  \
# 0        None  {u'created_time': u'1430159534', u'text': u'#w...
# 1        None  {u'created_time': u'1430159524', u'text': u'Hi...
# 2        None  {u'created_time': u'1430159508', u'text': u'To...
# 3        None  {u'created_time': u'1430159506', u'text': u'#n...
# 4        None  {u'created_time': u'1430159491', u'text': u'By...
#
#                      comments created_time    filter  \
# 0  {u'count': 0, u'data': []}   1430159534    Normal
# 1  {u'count': 0, u'data': []}   1430159524     Amaro
# 2  {u'count': 0, u'data': []}   1430159508  X-Pro II
# 3  {u'count': 0, u'data': []}   1430159506    Ludwig
# 4  {u'count': 0, u'data': []}   1430159491    Normal
#
#                               id  \
# 0  972571128369048408_1510978897
# 1   972571040076953064_190906948
# 2    972570907787524599_10750893
# 3   972570889394251028_176193768
# 4   972570765897195816_483823799
#
#                                               images  \
# 0  {u'low_resolution': {u'url': u'https://sconten...
# 1  {u'low_resolution': {u'url': u'https://sconten...
# 2  {u'low_resolution': {u'url': u'https://sconten...
# 3  {u'low_resolution': {u'url': u'https://sconten...
# 4  {u'low_resolution': {u'url': u'https://sconten...
#
#                                                likes  \
# 0                         {u'count': 0, u'data': []}
# 1  {u'count': 1, u'data': [{u'username': u'charmd...
# 2                         {u'count': 0, u'data': []}
# 3  {u'count': 2, u'data': [{u'username': u'dark19...
# 4  {u'count': 2, u'data': [{u'username': u'rainbo...
#
#                                   link  \
# 0  https://instagram.com/p/1_REnRPOtY/
# 1  https://instagram.com/p/1_RDVCnnXo/
# 2  https://instagram.com/p/1_RBZ1jfn3/
# 3  https://instagram.com/p/1_RBItOuUU/
# 4  https://instagram.com/p/1_Q_VsO2Eo/
#
#                                             location  \
# 0                                               None
# 1  {u'latitude': 40.644195785, u'longitude': -73....
# 2                                               None
# 3  {u'latitude': 40.758625, u'longitude': -73.978...
# 4                                               None
#
#                                                 tags   type  \
# 0  [weddingnyc, weddingphotography, newyorkcity, ...  image
# 1  [yummy, newyorkcity, food, abckitchen, foods, ...  image
# 2  [nyc, carlingsnyc, ccp, coastalcoinpockets, ne...  image
# 3  [hkig, newyorkcity, nyc, newyork, spring, 5tha...  image
# 4  [rockenespañol, concert, newyork, musician, ca...  image
#
#                                                 user  \
# 0  {u'username': u'silviafozphoto', u'profile_pic...
# 1  {u'username': u'neonedge', u'profile_picture':...
# 2  {u'username': u'jeanettefjortoft', u'profile_p...
# 3  {u'username': u'xxanxma', u'profile_picture': ...
# 4  {u'username': u'juanes_polonia', u'profile_pic...
#
#                                       users_in_photo videos  \
# 0                                                 []    NaN
# 1  [{u'position': {u'y': 0.313333333, u'x': 0.429...    NaN
# 2  [{u'position': {u'y': 0.5546296, u'x': 0.91851...    NaN
# 3                                                 []    NaN
# 4                                                 []    NaN
#
#                                                 text
# 0  #work #weddingphotography #wedding #weddingnyc...
# 1  Highly recommended to visit @abckitchen if you...
# 2  Too awesome to fit in one pic!👊 Takk for tide...
# 3  #nyc#newyork#newyorkcity#inlove#5thave#spring#...
# 4  By @cesarcalderonm "@Juanes || Barclays Center...

# %%
r = requests.get(url)

# %%
r = r.json()

# %%
tags = [x['tags'] for x in r['data']]
comments = [x['comments'] for x in r['data']]

# %%
pd.DataFrame?

# %%
df = pd.DataFrame(r['data'], index=None)

# %%
df['text'] = [x['text'] for x in df.caption]

#df['caption_cleaned'] = df['caption_clean'].str.extract('<(.*)>from')

# %%
df.caption[3]
# Out:
# {u'created_time': u'1429889242',
#  u'from': {u'full_name': u'Tiffanee Secoya Wilcox',
#   u'id': u'505183899',
#   u'profile_picture': u'https://igcdn-photos-a-a.akamaihd.net/hphotos-ak-xap1/t51.2885-19/925326_1442744206010080_2144939786_a.jpg',
#   u'username': u'tiffaneewilcox'},
#  u'id': u'970303749811401710',
#  u'text': u'Spring?\n#VSCOcam #vsco #vscogrid #vscofeature #newyorkcity #nyc #wanderlust #travel #explore #TFlers #love #photooftheday #20likes #amazing #picoftheday #instadaily #iphoneonly'}

# %%
df.caption_clean[3]
# Out:
# "'Spring?\\n#VSCOcam #vsco #vscogrid #vscofeature #newyorkcity #nyc #wanderlust #travel #explore #TFlers #love #photooftheday #20likes #amazing #picoftheday #instadaily #iphoneonly', u'from': {u'use"

# %%
type(df.caption)
# Out:
# pandas.core.series.Series

# %%
df['text'] = [x['text'] for x in df.caption]

# %%
from instagram.client import InstagramAPI

access_token = '14521798.768fcf1.f05c803b0a9c4c6dbac20060e0c2bc8d'
api = InstagramAPI(access_token=access_token)
recent_media, next_ = api.user_recent_media(user_id="userid", count=10)
for media in recent_media:
   print media.caption.text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-6a7e9594ccb2> in <module>()
#       3 access_token = '14521798.768fcf1.f05c803b0a9c4c6dbac20060e0c2bc8d'
#       4 api = InstagramAPI(access_token=access_token)
# ----> 5 recent_media, next_ = api.user_recent_media(user_id="userid", count=10)
#       6 for media in recent_media:
#       7    print media.caption.text
#
# /Users/olehdubno/anaconda/lib/python2.7/site-packages/instagram/bind.pyc in _call(api, *args, **kwargs)
#     194     def _call(api, *args, **kwargs):
#     195         method = InstagramAPIMethod(api, *args, **kwargs)
# --> 196         return method.execute()
#     197
#     198     return _call
#
# /Users/olehdubno/anaconda/lib/python2.7/site-packages/instagram/bind.pyc in execute(self)
#     180                                                                                  self.path,
#     181                                                                                  self.parameters,
# --> 182                                                                                  include_secret=self.include_secret)
#     183             if self.with_next_url:
#     184                 return self._get_with_next_url(self.with_next_url, method, body, headers)
#
# /Users/olehdubno/anaconda/lib/python2.7/site-packages/instagram/oauth2.pyc in prepare_request(self, method, path, params, include_secret)
#     222                 url = self._full_url(path, include_secret)
#     223             else:
# --> 224                 url = self._full_url_with_params(path, params, include_secret)
#     225         else:
#     226             body, headers = self._encode_multipart(params, params['files'])
#
# /Users/olehdubno/anaconda/lib/python2.7/site-packages/instagram/oauth2.pyc in _full_url_with_params(self, path, params, include_secret, include_signed_request)
#     146     def _full_url_with_params(self, path, params, include_secret=False, include_signed_request=True):
#     147         return (self._full_url(path, include_secret) +
# --> 148                 self._full_query_with_params(params) +
#     149                 self._signed_request(path, params, include_signed_request, include_secret))
#     150
#
# /Users/olehdubno/anaconda/lib/python2.7/site-packages/instagram/oauth2.pyc in _full_url(self, path, include_secret, include_signed_request)
#     142                                   path,
#     143                                   self._auth_query(include_secret),
# --> 144                                   self._signed_request(path, {}, include_signed_request, include_secret))
#     145
#     146     def _full_url_with_params(self, path, params, include_secret=False, include_signed_request=True):
#
# /Users/olehdubno/anaconda/lib/python2.7/site-packages/instagram/oauth2.pyc in _signed_request(self, path, params, include_signed_request, include_secret)
#     170             if include_secret and self.api.client_secret:
#     171                 params['client_secret'] = self.api.client_secret
# --> 172             return "&sig=%s" % self._generate_sig(path, params, self.api.client_secret)
#     173         else:
#     174             return ''
#
# /Users/olehdubno/anaconda/lib/python2.7/site-packages/instagram/oauth2.pyc in _generate_sig(self, endpoint, params, secret)
#     125         for key in sorted(params.keys()):
#     126             sig += '|%s=%s' % (key, params[key])
# --> 127         return  hmac.new(secret, sig, sha256).hexdigest()
#     128
#     129     def url_for_get(self, path, parameters):
#
# /Users/olehdubno/anaconda/python.app/Contents/lib/python2.7/hmac.pyc in new(key, msg, digestmod)
#     134     method.
#     135     """
# --> 136     return HMAC(key, msg, digestmod)
#
# /Users/olehdubno/anaconda/python.app/Contents/lib/python2.7/hmac.pyc in __init__(self, key, msg, digestmod)
#      69             blocksize = self.blocksize
#      70
# ---> 71         if len(key) > blocksize:
#      72             key = self.digest_cons(key).digest()
#      73
#
# TypeError: object of type 'NoneType' has no len()

# %%
client_id = '768fcf1f36c94eb08506bae0a9caffa3'
secret = '54efcbaed7f64673bc93b4e28ca9e8b2'

api = InstagramAPI(client_id=client_id, client_secret=secret)
popular_media = api.media_popular(count=20)
#for media in popular_media:
    #print media.comment_count, media.comments

# %%
# Out:
# datetime.datetime(2015, 4, 24, 8, 55, 35)

# %%
#when you query for a specific hashtag (e.g. 'newyorkcity')
#how many likes did a post get; likes
#captions
#tags *
#total amount of comments
#user
#filter *
#type of media *
#time *
#location *
#link *

# %%
import pandas as pd
import requests
import json

from pandas.io.json import json_normalize

client_id = '768fcf1f36c94eb08506bae0a9caffa3'
secret = '54efcbaed7f64673bc93b4e28ca9e8b2'
base_url = "https://api.instagram.com/v1"
query = "newyorkcity"

url = '{0}/tags/{1}/media/recent?client_id={2}&count=100'.format(base_url, query, client_id)

df = json_normalize(requests.get(url).json()['data'])

# %%
df = df[['user.username','caption.text','tags','comments.count','likes.count','filter','type','created_time','user.full_name','user.id','link','location.latitude','location.longitude']]

# %%
df.rename(columns={'user.username':'user_name',
                   'caption.text':'caption_text',
                   'tags':'hashtags',
                   'comments.count':'comments_count',
                   'likes.count':'likes_count',
                   'filter':'filter',
                   'created_time':'created_time',
                   'user.full_name':'full_name',
                   'user.id':'user_id',
                   'type':'type',
                   'link':'link',
                   'location.latitude':'latitude',
                   'location.longitude':'longitude'},
          inplace=True)

# %%
def hashtagsearch(hashtag):
    
    import pandas as pd
    import requests
    import json

    from pandas.io.json import json_normalize
    
    client_id = '768fcf1f36c94eb08506bae0a9caffa3'
    secret = '54efcbaed7f64673bc93b4e28ca9e8b2'
    base_url = "https://api.instagram.com/v1"
    query = hashtag
    
    url = '{0}/tags/{1}/media/recent?client_id={2}&count=100'.format(base_url, query, client_id)
    
    df = df[['user.username','caption.text','tags','comments.count','likes.count',
             'filter','type','created_time','user.full_name','user.id','link','location.latitude',
             'location.longitude']]
    
    df.rename(columns={'user.username':'user_name',
                   'caption.text':'caption_text',
                   'tags':'hashtags',
                   'comments.count':'comments_count',
                   'likes.count':'likes_count',
                   'filter':'filter',
                   'created_time':'created_time',
                   'user.full_name':'full_name',
                   'user.id':'user_id',
                   'type':'type',
                   'link':'link',
                   'location.latitude':'latitude',
                   'location.longitude':'longitude'},
          inplace=True)

    
    return df.head()

# %%
hashtagsearch('newyork')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-98-d565c47d828e> in <module>()
# ----> 1 hashtagsearch('newyork')
#
# <ipython-input-95-b74fee30f564> in hashtagsearch(hashtag)
#       8     url = '{0}/tags/{1}/media/recent?client_id={2}&count=100'.format(base_url, query, client_id)
#       9
# ---> 10     df = df[['user.username','caption.text','tags','comments.count','likes.count',
#      11              'filter','type','created_time','user.full_name','user.id','link','location.latitude',
#      12              'location.longitude']]
#
# UnboundLocalError: local variable 'df' referenced before assignment
